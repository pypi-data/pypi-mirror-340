# %%
from helper_loader import *

set_log_level("DEBUG")

# %%
from datetime import datetime
from itertools import product
import time

import pandas as pd
from scipy.spatial import KDTree

from histalign.backend.registration.alignment import interpolate_sparse_3d_array

# %%
def replace_workers_default(function: Callable, value: int) -> None:
    defaults = list(function.__defaults__)
    defaults[-1] = value
    function.__defaults__ = tuple(defaults)

# %%
alignment_path = Path(
    "/home/ediun/git/histalign/projects/project_cortical_depth/93e6cae680"
)

array = build_alignment_volume(alignment_path, return_raw_array=True)

mask = load_structure_mask("Isocortex", Resolution.MICRONS_25)
# Out:
# [2024-11-13 13:27:34] - [   DEBUG ] - Found cached volume. Loading from file. (histalign.backend.registration.alignment:55)

# %%
results_dataframe = pd.DataFrame(
    columns=[
        "worker_count",
        "neighbours_count",
        "chunk_size",
        "use_mask",
        "time",
    ],
)
results_dataframe = results_dataframe.astype(
    {
        "worker_count": int,
        "neighbours_count": int,
        "chunk_size": int,
        "use_mask": bool,
        "time": float,
    }
)

output_file_path = (
    f"resources/interpolation_benchmark_{datetime.now().strftime('%y_%m_%d-%H_%M')}.csv"
)

worker_counts = [1, -1]  # [16, -1]
neighbours_counts = [2**3, 3**3, 4**3]  # [3]
chunk_sizes = [1_000_000, 2_000_000, 4_000_000]  # [1_000_000]
use_mask_options = [True]  # [True]

for worker_count, neighbours_count, chunk_size, use_mask in product(
    worker_counts, neighbours_counts, chunk_sizes, use_mask_options
):
    start_time = time.perf_counter()

    replace_workers_default(KDTree.query, worker_count)
    interpolated_array = interpolate_sparse_3d_array(
        array,
        reference_mask=mask if use_mask else None,
        neighbours=neighbours_count,
        chunk_size=chunk_size,
        use_cache=False,
    )
    end_time = time.perf_counter()

    new_row = pd.DataFrame(
        [[worker_count, neighbours_count, chunk_size, use_mask, end_time - start_time]],
        columns=results_dataframe.columns,
    )
    results_dataframe = pd.concat([results_dataframe, new_row], ignore_index=True)

    results_dataframe.to_csv(output_file_path)
# Out:
# [2024-11-13 13:27:36] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 8, epsilon: 1, degree: None, chunk size: 1,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:27:36] - [    INFO ] - Interpolating chunk 1/8 (12%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:28:02] - [    INFO ] - Interpolating chunk 2/8 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:28:50] - [    INFO ] - Interpolating chunk 3/8 (38%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:29:38] - [    INFO ] - Interpolating chunk 4/8 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:30:20] - [    INFO ] - Interpolating chunk 5/8 (62%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:30:52] - [    INFO ] - Interpolating chunk 6/8 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:31:14] - [    INFO ] - Interpolating chunk 7/8 (88%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:31:31] - [    INFO ] - Interpolating chunk 8/8 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:31:46] - [    INFO ] - Finished interpolation in  4m11s. (histalign.backend.registration.alignment:294)
# [2024-11-13 13:31:48] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 8, epsilon: 1, degree: None, chunk size: 2,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:31:48] - [    INFO ] - Interpolating chunk 1/4 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:33:06] - [    INFO ] - Interpolating chunk 2/4 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:34:38] - [    INFO ] - Interpolating chunk 3/4 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:35:31] - [    INFO ] - Interpolating chunk 4/4 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:36:03] - [    INFO ] - Finished interpolation in  4m17s. (histalign.backend.registration.alignment:294)
# [2024-11-13 13:36:06] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 8, epsilon: 1, degree: None, chunk size: 4,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:36:06] - [    INFO ] - Interpolating chunk 1/2 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:38:53] - [    INFO ] - Interpolating chunk 2/2 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:40:17] - [    INFO ] - Finished interpolation in  4m14s. (histalign.backend.registration.alignment:294)
# [2024-11-13 13:40:19] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 27, epsilon: 1, degree: None, chunk size: 1,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:40:19] - [    INFO ] - Interpolating chunk 1/8 (12%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:40:54] - [    INFO ] - Interpolating chunk 2/8 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:41:53] - [    INFO ] - Interpolating chunk 3/8 (38%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:42:50] - [    INFO ] - Interpolating chunk 4/8 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:43:42] - [    INFO ] - Interpolating chunk 5/8 (62%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:44:24] - [    INFO ] - Interpolating chunk 6/8 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:44:55] - [    INFO ] - Interpolating chunk 7/8 (88%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:45:22] - [    INFO ] - Interpolating chunk 8/8 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:45:46] - [    INFO ] - Finished interpolation in  5m29s. (histalign.backend.registration.alignment:294)
# [2024-11-13 13:45:48] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 27, epsilon: 1, degree: None, chunk size: 2,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:45:48] - [    INFO ] - Interpolating chunk 1/4 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:47:31] - [    INFO ] - Interpolating chunk 2/4 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:49:27] - [    INFO ] - Interpolating chunk 3/4 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:50:42] - [    INFO ] - Interpolating chunk 4/4 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:51:34] - [    INFO ] - Finished interpolation in  5m47s. (histalign.backend.registration.alignment:294)
# [2024-11-13 13:51:36] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 27, epsilon: 1, degree: None, chunk size: 4,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:51:36] - [    INFO ] - Interpolating chunk 1/2 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:55:28] - [    INFO ] - Interpolating chunk 2/2 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:57:54] - [    INFO ] - Finished interpolation in  6m20s. (histalign.backend.registration.alignment:294)
# [2024-11-13 13:57:56] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 64, epsilon: 1, degree: None, chunk size: 1,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 13:57:56] - [    INFO ] - Interpolating chunk 1/8 (12%). (histalign.backend.registration.alignment:238)
# [2024-11-13 13:59:38] - [    INFO ] - Interpolating chunk 2/8 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:01:52] - [    INFO ] - Interpolating chunk 3/8 (38%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:04:31] - [    INFO ] - Interpolating chunk 4/8 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:06:41] - [    INFO ] - Interpolating chunk 5/8 (62%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:08:22] - [    INFO ] - Interpolating chunk 6/8 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:09:47] - [    INFO ] - Interpolating chunk 7/8 (88%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:11:16] - [    INFO ] - Interpolating chunk 8/8 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:12:37] - [    INFO ] - Finished interpolation in 14m43s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:12:39] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 64, epsilon: 1, degree: None, chunk size: 2,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:12:39] - [    INFO ] - Interpolating chunk 1/4 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:16:08] - [    INFO ] - Interpolating chunk 2/4 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:20:26] - [    INFO ] - Interpolating chunk 3/4 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:23:44] - [    INFO ] - Interpolating chunk 4/4 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:26:33] - [    INFO ] - Finished interpolation in 13m56s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:26:35] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 64, epsilon: 1, degree: None, chunk size: 4,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:26:35] - [    INFO ] - Interpolating chunk 1/2 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:34:49] - [    INFO ] - Interpolating chunk 2/2 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:41:36] - [    INFO ] - Finished interpolation in 15m 3s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:41:38] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 8, epsilon: 1, degree: None, chunk size: 1,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:41:38] - [    INFO ] - Interpolating chunk 1/8 (12%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:41:43] - [    INFO ] - Interpolating chunk 2/8 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:41:48] - [    INFO ] - Interpolating chunk 3/8 (38%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:41:54] - [    INFO ] - Interpolating chunk 4/8 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:41:59] - [    INFO ] - Interpolating chunk 5/8 (62%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:03] - [    INFO ] - Interpolating chunk 6/8 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:07] - [    INFO ] - Interpolating chunk 7/8 (88%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:09] - [    INFO ] - Interpolating chunk 8/8 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:12] - [    INFO ] - Finished interpolation in 36s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:42:13] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 8, epsilon: 1, degree: None, chunk size: 2,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:42:13] - [    INFO ] - Interpolating chunk 1/4 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:23] - [    INFO ] - Interpolating chunk 2/4 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:34] - [    INFO ] - Interpolating chunk 3/4 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:42] - [    INFO ] - Interpolating chunk 4/4 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:42:47] - [    INFO ] - Finished interpolation in 35s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:42:48] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 8, epsilon: 1, degree: None, chunk size: 4,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:42:48] - [    INFO ] - Interpolating chunk 1/2 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:43:08] - [    INFO ] - Interpolating chunk 2/2 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:43:24] - [    INFO ] - Finished interpolation in 37s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:43:25] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 27, epsilon: 1, degree: None, chunk size: 1,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:43:26] - [    INFO ] - Interpolating chunk 1/8 (12%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:43:38] - [    INFO ] - Interpolating chunk 2/8 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:43:55] - [    INFO ] - Interpolating chunk 3/8 (38%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:44:09] - [    INFO ] - Interpolating chunk 4/8 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:44:25] - [    INFO ] - Interpolating chunk 5/8 (62%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:44:39] - [    INFO ] - Interpolating chunk 6/8 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:44:50] - [    INFO ] - Interpolating chunk 7/8 (88%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:45:00] - [    INFO ] - Interpolating chunk 8/8 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:45:10] - [    INFO ] - Finished interpolation in  1m46s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:45:11] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 27, epsilon: 1, degree: None, chunk size: 2,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:45:11] - [    INFO ] - Interpolating chunk 1/4 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:45:42] - [    INFO ] - Interpolating chunk 2/4 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:46:14] - [    INFO ] - Interpolating chunk 3/4 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:46:40] - [    INFO ] - Interpolating chunk 4/4 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:47:03] - [    INFO ] - Finished interpolation in  1m53s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:47:05] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 27, epsilon: 1, degree: None, chunk size: 4,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:47:06] - [    INFO ] - Interpolating chunk 1/2 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:48:10] - [    INFO ] - Interpolating chunk 2/2 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:49:15] - [    INFO ] - Finished interpolation in  2m11s. (histalign.backend.registration.alignment:294)
# [2024-11-13 14:49:17] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 64, epsilon: 1, degree: None, chunk size: 1,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 14:49:18] - [    INFO ] - Interpolating chunk 1/8 (12%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:51:26] - [    INFO ] - Interpolating chunk 2/8 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:53:29] - [    INFO ] - Interpolating chunk 3/8 (38%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:55:17] - [    INFO ] - Interpolating chunk 4/8 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:57:31] - [    INFO ] - Interpolating chunk 5/8 (62%). (histalign.backend.registration.alignment:238)
# [2024-11-13 14:59:18] - [    INFO ] - Interpolating chunk 6/8 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:00:17] - [    INFO ] - Interpolating chunk 7/8 (88%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:01:17] - [    INFO ] - Interpolating chunk 8/8 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:02:37] - [    INFO ] - Finished interpolation in 13m22s. (histalign.backend.registration.alignment:294)
# [2024-11-13 15:02:39] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 64, epsilon: 1, degree: None, chunk size: 2,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 15:02:39] - [    INFO ] - Interpolating chunk 1/4 (25%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:06:02] - [    INFO ] - Interpolating chunk 2/4 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:09:49] - [    INFO ] - Interpolating chunk 3/4 (75%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:13:49] - [    INFO ] - Interpolating chunk 4/4 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:16:12] - [    INFO ] - Finished interpolation in 13m36s. (histalign.backend.registration.alignment:294)
# [2024-11-13 15:16:15] - [    INFO ] - Starting interpolation with parameters {kernel: multiquadric, neighbours: 64, epsilon: 1, degree: None, chunk size: 4,000,000, recursive: False}. (histalign.backend.registration.alignment:204)
# [2024-11-13 15:16:16] - [    INFO ] - Interpolating chunk 1/2 (50%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:23:25] - [    INFO ] - Interpolating chunk 2/2 (100%). (histalign.backend.registration.alignment:238)
# [2024-11-13 15:29:51] - [    INFO ] - Finished interpolation in 13m38s. (histalign.backend.registration.alignment:294)

# %%
results_dataframe
# Out:
#     worker_count  neighbours_count  chunk_size  use_mask        time
# 0              1                 8     1000000      True  251.440988
# 1              1                 8     2000000      True  257.203675
# 2              1                 8     4000000      True  253.615925
# 3              1                27     1000000      True  329.167434
# 4              1                27     2000000      True  347.489357
# 5              1                27     4000000      True  379.910391
# 6              1                64     1000000      True  883.013129
# 7              1                64     2000000      True  836.081551
# 8              1                64     4000000      True  903.279962
# 9             -1                 8     1000000      True   35.730645
# 10            -1                 8     2000000      True   35.118524
# 11            -1                 8     4000000      True   36.805839
# 12            -1                27     1000000      True  106.407889
# 13            -1                27     2000000      True  113.326959
# 14            -1                27     4000000      True  131.135645
# 15            -1                64     1000000      True  802.209781
# 16            -1                64     2000000      True  815.563175
# 17            -1                64     4000000      True  818.314641

# %%
results_dataframe[results_dataframe.chunk_size == 1_000_000].groupby(
    ["worker_count", "neighbours_count"]
).time.mean()
# Out:
# worker_count  neighbours_count
# -1            8                    35.730645
#               27                  106.407889
#               64                  802.209781
#  1            8                   251.440988
#               27                  329.167434
#               64                  883.013129
# Name: time, dtype: float64
