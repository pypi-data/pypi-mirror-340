# %%
import logging

from histalign.backend.new import build_alignment_volume

# %%
logging.basicConfig(level=logging.DEBUG)

# %%
volume = build_alignment_volume(
    "/home/ediun/git/histalign/projects/project_310724_partial/7d9af388b0"
)
# Out:
# DEBUG:histalign.backend.new:Generating meshes.
# DEBUG:histalign.backend.new:Generating meshes.
# DEBUG:histalign.backend.new:Generated 0 meshes...
# DEBUG:histalign.backend.new:Generated 0 meshes...
# DEBUG:histalign.backend.new:Gathering meshes into alignment volume.
# DEBUG:histalign.backend.new:Gathering meshes into alignment volume.
# DEBUG:histalign.backend.new:Gathered 0 meshes...
# DEBUG:histalign.backend.new:Gathered 0 meshes...

# %%
volume.clone().cmap("Blues", alpha=[0, 1], vmin=0, vmax=2**16 - 1)
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Volume: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/volume.html" target="_blank">vedo.volume.Volume</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 527.0<br/>0 ... 319.0<br/>0 ... 455.0</td></tr>
# <tr><td><b> dimensions </b></td><td>(528, 320, 456)</td></tr>
# <tr><td><b> voxel spacing </b></td><td>(1.00, 1.00, 1.00)</td></tr>
# <tr><td><b> in memory size </b></td><td>146MB</td></tr>
# <tr><td><b> point data array </b></td><td>input_scalars</td></tr>
#
# <tr><td><b> scalar range </b></td><td>(0, 6.554e+4)</td></tr>
# </table>
# </table>
