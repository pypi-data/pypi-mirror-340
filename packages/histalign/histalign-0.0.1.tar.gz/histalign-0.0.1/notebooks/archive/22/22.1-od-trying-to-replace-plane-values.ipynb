# %%
import numpy as np
import vedo

from notebook_helpers import *

# %%
array1 = construct_cardboard_box(shape=(20,) * 3)

volume1 = vedo.Volume(array1)
volume1.cmap("red", alpha=[0, 1], vmin=0, vmax=255)
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Volume: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/volume.html" target="_blank">vedo.volume.Volume</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 19.00<br/>0 ... 19.00<br/>0 ... 19.00</td></tr>
# <tr><td><b> dimensions </b></td><td>(20, 20, 20)</td></tr>
# <tr><td><b> voxel spacing </b></td><td>(1.00, 1.00, 1.00)</td></tr>
# <tr><td><b> in memory size </b></td><td>0MB</td></tr>
# <tr><td><b> point data array </b></td><td>input_scalars</td></tr>
#
# <tr><td><b> scalar range </b></td><td>(0, 255.0)</td></tr>
# </table>
# </table>

# %%
plane = volume1.slice_plane(origin=volume1.center(), normal=(0, 0.5, 0.5))

show(plane)

# %%
plane.tovolume(n=100)
# Out:
# <table>
# <tr>
# <td>
# <img src='data:image/png;base64,...'></img>
# </td>
# <td style='text-align: center; vertical-align: center;'><br/>
# <b> Volume: &nbsp&nbsp</b><b><a href="https://vedo.embl.es/docs/vedo/volume.html" target="_blank">vedo.volume.Volume</a></b>
# <table>
# <tr><td><b> bounds </b> <br/> (x/y/z) </td><td>0 ... 18.24<br/>-1.324e-7 ... 18.33<br/>-0.09188 ... 18.24</td></tr>
# <tr><td><b> dimensions </b></td><td>(25, 25, 25)</td></tr>
# <tr><td><b> voxel spacing </b></td><td>(0.760, 0.764, 0.764)</td></tr>
# <tr><td><b> in memory size </b></td><td>0MB</td></tr>
# <tr><td><b> point data array </b></td><td>ImageScalars</td></tr>
#
# <tr><td><b> scalar range </b></td><td>(0, 252.5)</td></tr>
# </table>
# </table>
