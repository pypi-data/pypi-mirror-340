# %% [markdown]
# ## Подключение к PT NAD
#
# ptnad-client позволяет выполнять запросы к системе с использованием различных способов аутентификации.
#
# ### Локальное подключение
#
# Для быстрого тестирования и отладки можно использовать локальное подключение. В качестве дефолтных значений используется логин "administrator" и пароль "Administr@t0r".

# %%
from ptnad import PTNADClient

# Подключение к локальному инстансу PT NAD (пример для тестовой среды)
client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)

# Установка логина и пароля
client.set_auth(username="administrator", password="Administr@t0r")

# Подключаемся к сервису
client.login()

# %% [markdown]
# ### Подключение через SSO
#
# Для подключения через SSO необходимо использовать auth_type="sso" и параметры, которые можно получить из файла /opt/ptsecurity/etc/iam_cookie.json на сервере PT NAD.
#
# Пример структуры, получаемой при выводе содержимого "iam_cookie.json":
#
# ```bash
# cat /opt/ptsecurity/etc/iam_cookie.json
# ```
#
# ```json
# {
#     "iam": {
#         "id": "your_id",
#         "name": "PTLAB NAD",
#         "redirect_url": "https://ptlab-nad.ptlab.ptsecurity.ru",
#         "secret": "your_secret",
#         "token": "your_token",
#         "token_type": "reference",
#         "url": "https://ptlab-core.ptlab.ptsecurity.ru:3334",
#         "verify": false
#     },
#     "tms": {
#         "app_id": "your_app_id",
#         "display_name": "PTLAB NAD",
#         "endpoint": "https://ptlab-nad.ptlab.ptsecurity.ru",
#         "request_id": "your_request_id",
#         "token": "your_token",
#         "url": "https://ptlab-core.ptlab.ptsecurity.ru:3334"
#     }
# }
# ```
#
# Для подключения, необходимо взять информацию из ключей "app_id", "secret" и "url".
# В качестве auth_type указываем "sso", добавляем свои логин/пароль и оставшиеся поля из iam_cookie.json, где
# - client_id = id
# - client_secret = secret
# - sso_url = url
#
# По итогу получаем:
#
# ```python
# client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)
# client.set_auth(
#     auth_type="sso",
#     username="user",
#     password="pass",
#     client_id="your_id",
#     client_secret="your_secret",
#     sso_url="https://ptlab-core.ptlab.ptsecurity.ru:3334"
# )
# client.login()
# ```
#
# Ссылка на код, где можно подробнее изучить механизмы авторизации: [Code Reference](https://reversenant.github.io/ptnad-client-test/reference/)

# %% [markdown]
# ### Примеры работы с библиотекой

# %% [markdown]
# #### BQL-запросы
#
# В этом примере демонстрируется работа с кастомными фильтрами, хранящимися в файле "docs\data\pilot_filters.json", и выполнение BQL-запросов к PT NAD. Для примера выберем только два поля: IP-адрес источника (src.ip) и IP-адрес назначения (dst.ip). Также ограничим вывод фильтров - по одному на каждую категорию, по 3 события:
# - Локально подключаемся PT NAD.
# - Загружаем фильтры из файла pilot_filters.json, где каждый фильтр содержит BQL-фрагмент, имя и категорию (есть возможность выбора языка).
# - Формируем базовый запрос с временным диапазоном (последние 3 дня).
# - Объединяем базовый запрос с фильтрами.
# - Группируем запросы по категориям.
# - Выполняем каждый запрос и выводим результаты с указанием:
#     - категории фильтра;
#     - его названия;
#     - полного BQL-запроса;
#     - результата.
#
# Более подробно про возможные параметры фильтрации и их значения можно почитать тут - [PT NAD Справка](https://help.ptsecurity.com/ru-RU/projects/nad/12.2/help/7083891595)

# %%
import json
from datetime import datetime, timedelta
from ptnad import PTNADClient

client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)
client.set_auth(username="administrator", password="Administr@t0r")
client.login()

with open("../data/pilot_filters.json", "r", encoding="utf-8") as f:
    data = json.load(f)

now = datetime.now()
start_time = (now - timedelta(days=3)).strftime("%Y-%m-%dT%H:%M:%S")
end_time = now.strftime("%Y-%m-%dT%H:%M:%S")

base_query = f"SELECT src.ip, dst.ip FROM flow WHERE start > '{start_time}' AND end < '{end_time}'"

grouped_queries = {}

for item in data["filters"]:
    category = item["category"]["ru"]
    name = item["name"]["ru"]
    filter_query = item["filter"].strip()

    if filter_query:
        full_query = f"{base_query} AND ({filter_query})"
        if category not in grouped_queries:
            grouped_queries[category] = []
        grouped_queries[category].append((name, full_query))

for category, filters in grouped_queries.items():
    print(f"\n▶️ Категория: {category}")
    for name, query in filters[:1]:
        result = client.bql.execute(query)
        print(f"\n🔹 {name}\n{query}")
        print("Results:")
        if isinstance(result, list) and result:
            for i, row in enumerate(result[:3], 1):
                print(f"{i}. {row}")
        else:
            print("Нет результатов.")
# Out:
# ▶️ Категория: Протоколы
#
# 🔹 Telnet
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (app_proto == 'telnet')
# Results:
# Нет результатов.
#
# ▶️ Категория: Данные
#
# 🔹 Сессии с файлами
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (files)
# Results:
# 1. ['10.125.9.10', '10.125.136.66']
# 2. ['10.125.143.4', '23.210.252.238']
# 3. ['10.125.9.10', '10.125.136.66']
#
# ▶️ Категория: Анонимность
#
# 🔹 OpenVPN
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (app_proto == openvpn)
# Results:
# Нет результатов.
#
# ▶️ Категория: Сеть
#
# 🔹 Трафик без доменного имени
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (dst.groups != 'HOME_NET' && !dst.dns)
# Results:
# 1. ['10.125.101.6', '10.158.2.22']
# 2. ['10.125.126.5', '10.158.6.143']
# 3. ['10.125.101.3', '10.158.2.22']
#
# ▶️ Категория: Веб
#
# 🔹 Digital Ocean
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (dst.geo.org == 'DigitalOcean, LLC' || dst.geo.org == 'Amazon.com, Inc.')
# Results:
# Нет результатов.
#
# ▶️ Категория: Мессенджеры
#
# 🔹 Telegram
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (alert.msg == 'APP [PTsecurity] Telegram Messenger v3 HTTP' || alert.msg == 'APP [PTsecurity] Telegram Messenger v2' || alert.msg == 'APP [PTsecurity] Telegram Messenger')
# Results:
# Нет результатов.
#
# ▶️ Категория: Домен
#
# 🔹 Авторизация по LDAP
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (credentials.password and app_proto == 'ldap')
# Results:
# 1. ['10.125.135.21', '10.125.130.4']
# 2. ['10.125.135.21', '10.125.130.4']
# 3. ['10.125.135.21', '10.125.130.4']
#
# ▶️ Категория: Удаленное управление
#
# 🔹 TeamViewer 1
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (dst.dns ~ '*.teamviewer.com')
# Results:
# Нет результатов.
#
# ▶️ Категория: Атаки
#
# 🔹 Реп. списки и правила
# SELECT src.ip, dst.ip FROM flow WHERE start > '2025-04-07T12:44:18' AND end < '2025-04-10T12:44:18' AND (rpt.cat && alert)
# Results:
# 1. ['10.125.255.95', '10.125.122.4']
# 2. ['10.125.255.95', '10.125.122.4']
# 3. ['10.125.255.95', '10.125.122.4']

# %% [markdown]
# #### Monitoring

# %% [markdown]
# Получение общего статуса системы:

# %%
from ptnad import PTNADClient
from ptnad.api.monitoring import MonitoringAPI

client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)
client.set_auth(username="administrator", password="Administr@t0r")
client.login()

monitoring = MonitoringAPI(client)

status = monitoring.get_status()

print(f"Статус: {status.status}")
for problem in status.problems:
    print(f"{problem}")
# Out:
# Статус: green

# %% [markdown]
# Получение списка всех триггеров

# %%
from ptnad import PTNADClient
from ptnad.api.monitoring import MonitoringAPI

client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)
client.set_auth(username="administrator", password="Administr@t0r")
client.login()

monitoring = MonitoringAPI(client)

triggers = monitoring.get_triggers()

for trig in triggers:
    print(f"\nTrigger ID: {trig.id}")
    print(f"Тип: {trig.type}")
    print(f"Статус: {trig.status}")
    print(f"Последнее обновление: {trig.updated}")
# Out:
# Trigger ID: ptdpi-broker_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887068Z
#
# Trigger ID: ptdpi-worker@es_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887172Z
#
# Trigger ID: ptdpi-worker@dns_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887252Z
#
# Trigger ID: nad-reporter_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887324Z
#
# Trigger ID: pyfpta_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887387Z
#
# Trigger ID: task-server_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887439Z
#
# Trigger ID: mgmt-server_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887501Z
#
# Trigger ID: elastic_unavailable
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887559Z
#
# Trigger ID: elastic_status
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887625Z
#
# Trigger ID: elastic_freespace
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887697Z
#
# Trigger ID: es_drops
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887838Z
#
# Trigger ID: ptdpistat_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.887922Z
#
# Trigger ID: ptdpi-worker@ad_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888066Z
#
# Trigger ID: ptdpi-worker@alert_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888208Z
#
# Trigger ID: ptdpi-worker@hosts_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888335Z
#
# Trigger ID: ptdpi-worker@icap_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888403Z
#
# Trigger ID: ptdpi-worker@mpx_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888487Z
#
# Trigger ID: nad-mpx-reader_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888578Z
#
# Trigger ID: ptdpi-worker@notifier_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888678Z
#
# Trigger ID: mgmt-client_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.888878Z
#
# Trigger ID: ptdpi_unavailable[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889034Z
#
# Trigger ID: no_traffic[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889154Z
#
# Trigger ID: capture_drops[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889274Z
#
# Trigger ID: dpi_resource[sensor][defrag.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889397Z
#
# Trigger ID: dpi_resource[sensor][file_reassembler.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889488Z
#
# Trigger ID: dpi_resource[sensor][files.disk_used]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889543Z
#
# Trigger ID: dpi_resource[sensor][flow.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889581Z
#
# Trigger ID: dpi_resource[sensor][host.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889617Z
#
# Trigger ID: dpi_resource[sensor][ippair.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889687Z
#
# Trigger ID: dpi_resource[sensor][pcap.buf.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889794Z
#
# Trigger ID: dpi_resource[sensor][segment.memuse]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.889863Z
#
# Trigger ID: pcap_drops[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.890079Z
#
# Trigger ID: pcap_io_error[sensor]
# Тип: stats
# Статус: green
# Последнее обновление: 2025-04-10T09:36:21.890160Z
#
# Trigger ID: updates[PTSecurity]
# Тип: updates
# Статус: green
# Последнее обновление: 2025-04-10T09:17:41.668648Z

# %% [markdown]
# #### Replists

# %% [markdown]
# Получение всех списков

# %%
from ptnad import PTNADClient
from ptnad.api.replists import RepListsAPI

client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)
client.set_auth(username="administrator", password="Administr@t0r")
client.login()

replists = RepListsAPI(client)

lists = replists.get_all_lists()
print(f"Общее количество: {len(lists)}")

for r in lists:
    print(f"- [{r['id']}] {r['name']} ({r['type']}, items: {r['items_count']})")
# Out:
# Общее количество: 954
# - [24858] ESC-manual-mekotio-ip (ip, items: 1)
# - [14896] malware (md5, items: 2856)
# - [24311] ESC-auto-spyder-ip (ip, items: 1)
# - [25318] ESC-auto-mispadu-ip (ip, items: 1)
# - [25984] ESC-auto-apt35-ip (ip, items: 2)
# - [23653] ESC-auto-apt28-ip (ip, items: 2)
# - [23000] ESC-manual-gsocket-ip (ip, items: 6)
# - [26133] ESC-manual-pocorat-ip (ip, items: 1)
# - [24067] ESC-manual-bandook-ip (ip, items: 1)
# - [23001] ESC-manual-stickywerewolf-darktrack-ip (ip, items: 1)
# - [23002] ESC-auto-stargazer_goblin-ip (ip, items: 1)
# - [25141] ESC-auto-chamelgang-ip (ip, items: 1)
# - [25153] ESC-auto-darkcomet-ip (ip, items: 1)
# - [25075] ESC-auto-warmcookie-ip (ip, items: 1)
# - [2118] ESC-auto-cloudeye-ip (ip, items: 19)
# - [25094] ESC-auto-valleyrat-ip (ip, items: 2)
# - [25028] ESC-auto-anchormail-ip (ip, items: 1)
# - [20532] ESC-auto-icedid-ip (ip, items: 7)
# - [24768] ESC-auto-purplefox-ip (ip, items: 1)
# - [21733] ESC-auto-prometei-ip (ip, items: 2)
# - [23861] ESC-exploitation_iocs-ip (ip, items: 4655)
# - [20302] ESC-auto-brute_ratel-ip (ip, items: 9)
# - [23007] ESC-auto-lazarus_group-ip (ip, items: 6)
# - [22312] ESC-auto-strelastealer-ip (ip, items: 4)
# - [22313] ESC-manual-lifting_zmiy-ip (ip, items: 25)
# - [23008] ESC-auto-other-ip (ip, items: 295)
# - [25113] ESC-auto-gelsemium-ip (ip, items: 1)
# - [23009] ESC-auto-dev-0960-ip (ip, items: 1)
# - [24499] ESC-auto-phantomdl-ip (ip, items: 2)
# - [23010] ESC-manual-erbium-ip (ip, items: 1)
# - [25473] ESC-auto-mykings_spreader-ip (ip, items: 1)
# - [24489] ESC-manual-other-ip (ip, items: 12)
# - [25319] ESC-manual-havoc-ip (ip, items: 3)
# - [25624] ESC-auto-ransomhub-ip (ip, items: 1)
# - [26134] ESC-auto-apt-c-09-dns (dn, items: 1)
# - [26135] ESC-manual-medusa-dns (dn, items: 1)
# - [26136] ESC-manual-xddown-dns (dn, items: 2)
# - [25101] ESC-auto-sectoprat-ip (ip, items: 9)
# - [20688] ESC-auto-nanocore-ip (ip, items: 38)
# - [20307] ESC-auto-monero_miner-ip (ip, items: 8)
# - [22918] ESC-manual-dcrat-ip (ip, items: 1)
# - [9109] ESC-manual-ta558-ip (ip, items: 17)
# - [20690] ESC-auto-targetcompany-ip (ip, items: 2)
# - [19661] ESC-auto-systembc-ip (ip, items: 8)
# - [23013] ESC-manual-microcin-ip (ip, items: 1)
# - [23014] ESC-manual-lanmanserver-ip (ip, items: 1)
# - [23015] ESC-manual-dratzarus-ip (ip, items: 1)
# - [4299] ESC-auto-vidar-ip (ip, items: 216)
# - [24940] ESC-auto-scaly_wolf-ip (ip, items: 1)
# - [25157] ESC-auto-metastealer-ip (ip, items: 2)
# - [25013] ESC-auto-ta570-ip (ip, items: 1)
# - [24490] ESC-auto-xor_ddos-ip (ip, items: 1)
# - [19665] ESC-auto-zeuspanda-ip (ip, items: 2)
# - [25158] ESC-auto-ta558-ip (ip, items: 2)
# - [19849] ESC-manual-cloud_atlas-ip (ip, items: 10)
# - [24876] ESC-manual-space_pirates-ip (ip, items: 7)
# - [24375] ESC-auto-modernloader-ip (ip, items: 1)
# - [25014] ESC-auto-gsocket-ip (ip, items: 1)
# - [25096] ESC-auto-ligolo-ip (ip, items: 1)
# - [25097] ESC-auto-disgomoji-ip (ip, items: 1)
# - [24877] ESC-auto-lumma-ip (ip, items: 25)
# - [23488] ESC-manual-winelab-ip (ip, items: 1)
# - [23020] ESC-auto-apt43-ip (ip, items: 1)
# - [25159] ESC-auto-gamaredon-ip (ip, items: 1)
# - [25099] ESC-auto-mythic_c2-ip (ip, items: 193)
# - [25434] ESC-auto-chtonic-ip (ip, items: 1)
# - [24389] ESC-auto-anubis_stealer-ip (ip, items: 1)
# - [25259] ESC-auto-comet-ip (ip, items: 1)
# - [25320] ESC-manual-gophish-ip (ip, items: 2)
# - [25853] ESC-auto-banload-ip (ip, items: 1)
# - [25475] ESC-auto-purelogs-ip (ip, items: 1)
# - [26068] ESC-auto-coldstealer-dns (dn, items: 1)
# - [26137] ESC-manual-darkgaboon-dns (dn, items: 9)
# - [26138] ESC-manual-trojan-downloader-dns (dn, items: 1)
# - [4129] ESC-auto-raccoon-ip (ip, items: 15)
# - [20647] ESC-auto-hajime-ip (ip, items: 39)
# - [21382] ESC-auto-teamspy-ip (ip, items: 1)
# - [21283] ESC-auto-floxif-ip (ip, items: 1)
# - [20658] ESC-auto-azorult-ip (ip, items: 4)
# - [20659] ESC-auto-bianlian-ip (ip, items: 6)
# - [2186] ESC-auto-dcrat-ip (ip, items: 214)
# - [19669] ESC-auto-socks5_systemz-ip (ip, items: 2)
# - [20851] ESC-manual-medusastealer-ip (ip, items: 1)
# - [22282] ESC-auto-pikabot-ip (ip, items: 6)
# - [23024] ESC-manual-quasarrat-ip (ip, items: 1)
# - [21360] ESC-auto-upatre-ip (ip, items: 2)
# - [20328] ESC-auto-shadowpad-ip (ip, items: 12)
# - [2295] ESC-auto-formbook-ip (ip, items: 23)
# - [24657] ESC-auto-hook-ip (ip, items: 8)
# - [23025] ESC-auto-darkgaboon-ip (ip, items: 1)
# - [25161] ESC-auto-markopolo-ip (ip, items: 1)
# - [25076] ESC-auto-ostap-ip (ip, items: 70)
# - [25077] ESC-auto-beacon-ip (ip, items: 2)
# - [23026] ESC-auto-lockbit_group-ip (ip, items: 8)
# - [24880] ESC-manual-cobalt_strike-ip (ip, items: 6)
# - [23027] ESC-manual-lumma-ip (ip, items: 1)
# - [25162] ESC-auto-latrodectus-ip (ip, items: 4)
# - [23029] ESC-manual-sysupdate-ip (ip, items: 2)
# - [25016] ESC-auto-bazarbackdoor-ip (ip, items: 2)
# - [22737] ESC-auto-poison_ivy-ip (ip, items: 1)
# - [25102] ESC-auto-darkgate-ip (ip, items: 1)
# - [24863] ESC-auto-mekotio-ip (ip, items: 4)
# - [24320] ESC-manual-koiloader-ip (ip, items: 1)
# - [24874] unknown_apt_031525_ip (ip, items: 4)
# - [23751] ESC-auto-ficker_stealer-ip (ip, items: 1)
# - [25329] ESC-manual-ir-inc-unk-072024-ip (ip, items: 1)
# - [25660] ESC-auto-royal_ransom-dns (dn, items: 2)
# - [25959] ESC-auto-hilalrat-dns (dn, items: 1)
# - [26069] ESC-manual-other-dns (dn, items: 3)
# - [26139] ESC-manual-decoydog-dns (dn, items: 1)
# - [26140] ESC-auto-lockbit_group-dns (dn, items: 1)
# - [8316] ESC-manual-excobalt-ip (ip, items: 22)
# - [2207] ESC-auto-mirai-ip (ip, items: 801)
# - [21390] ESC-auto-cobian_rat-ip (ip, items: 1)
# - [23132] unknown_apt_022025_ip (ip, items: 7)
# - [23621] ESC-auto-hyperbro-ip (ip, items: 1)
# - [24076] ESC-manual-kazn-ip (ip, items: 1)
# - [25142] ESC-auto-adwind-ip (ip, items: 1)
# - [25104] ESC-auto-supershell-ip (ip, items: 4)
# - [23033] ESC-auto-keksec-ip (ip, items: 1)
# - [25164] ESC-auto-emmenhtal-ip (ip, items: 4)
# - [25133] ESC-auto-ta866-ip (ip, items: 1)
# - [23600] ESC-manual-goffee-ip (ip, items: 3)
# - [25018] ESC-auto-dridex-ip (ip, items: 6)
# - [25117] ESC-auto-empire_downloader-ip (ip, items: 1)
# - [25166] ESC-auto-predator-dns (dn, items: 1)
# - [24883] ESC-manual-cobalt_strike-dns (dn, items: 11)
# - [24077] ET_alert_rules_Qwerty (dn, items: 1)
# - [19980] ET_alert_rules_compromised_website (dn, items: 19)
# - [24020] ESC-auto-poet_rat-dns (dn, items: 1)
# - [25169] ESC-auto-doplugs-dns (dn, items: 1)
# - [25377] ESC-auto-spark_rat-dns (dn, items: 1)
# - [25820] ESC-auto-zebrocy-dns (dn, items: 1)
# - [24700] ESC-auto-marcher-dns (dn, items: 146)
# - [25119] ESC-auto-deloader-dns (dn, items: 1)
# - [25170] ESC-auto-xdspy-dns (dn, items: 1)
# - [25960] ESC-auto-apt35-dns (dn, items: 5)
# - [25479] ESC-auto-blackcat-dns (dn, items: 1)
# - [25948] ESC-auto-curium-dns (dn, items: 1)
# - [19984] ET_alert_rules_Exploit_Kit (dn, items: 3)
# - [19732] ESC-auto-ave_maria-dns (dn, items: 4)
# - [11547] ET_alert_rules_BlackTech (dn, items: 1)
# - [25508] ESC-auto-valleyrat-dns (dn, items: 1)
# - [26047] ESC-auto-binder-dns (dn, items: 1)
# - [11669] ET_alert_rules_Gamaredon (dn, items: 51)
# - [26141] ESC-manual-hive0117-darkwatchman-dns (dn, items: 72)
# - [20424] ESC-manual-asyncrat-dns (dn, items: 1)
# - [26142] ESC-manual-msngrt_downloader-dns (dn, items: 1)
# - [2191] ESC-auto-remcos-ip (ip, items: 190)
# - [21788] ESC-manual-rarewolf-ip (ip, items: 2)
# - [4841] ESC-auto-smokeloader-ip (ip, items: 17)
# - [23038] ESC-auto-blackcat-ip (ip, items: 1)
# - [11469] ET_alert_rules_Zanubis (dn, items: 1)
# - [11470] ET_alert_rules_DPRK (dn, items: 5)
# - [15437] ET_alert_rules_Vultur (dn, items: 2)
# - [11471] ET_alert_rules_PlugX (dn, items: 2)
# - [17704] ET_alert_rules_Anonymous (dn, items: 1)
# - [20861] ESC-auto-rustbucket-dns (dn, items: 1)
# - [4259] ESC-auto-cloudeye-dns (dn, items: 7)
# - [24909] ESC-auto-guildma-dns (dn, items: 37)
# - [25171] ESC-auto-xmrig-dns (dn, items: 4)
# - [25033] ESC-auto-dridex-dns (dn, items: 20)
# - [24100] ESC-auto-sality-dns (dn, items: 2)
# - [11532] ET_alert_rules_Symbiote (dn, items: 5)
# - [11533] ET_alert_rules_APT_C_48 (dn, items: 2)
# - [19725] ESC-auto-chrysaor-dns (dn, items: 4)
# - [23052] ESC-manual-snakekeylogger-dns (dn, items: 1)
# - [11534] ET_alert_rules_Mercury (dn, items: 1)
# - [11535] ET_alert_rules_Gallium (dn, items: 2)
# - [11536] ET_alert_rules_StealerOne (dn, items: 1)
# - [20582] ESC-auto-andromeda-dns (dn, items: 1)
# - [11537] ET_alert_rules_Nitrokod (dn, items: 3)
# - [23717] ESC-auto-ficker_stealer-dns (dn, items: 7)
# - [25174] ESC-auto-purelogs-dns (dn, items: 2)
# - [11539] ET_alert_rules_CloudAtlas (dn, items: 1)
# - [25728] ESC-auto-magania-dns (dn, items: 1)
# - [25729] ESC-auto-phantomdl-dns (dn, items: 1)
# - [25962] ESC-auto-medusalocker-dns (dn, items: 6)
# - [25730] ESC-auto-darkwatchman-dns (dn, items: 42)
# - [24411] ESC-auto-havoc-dns (dn, items: 6)
# - [21905] ESC-auto-deathransom-dns (dn, items: 1)
# - [20886] ESC-auto-bluenoroff-dns (dn, items: 1)
# - [26143] ESC-auto-pseudogamaredon-dns (dn, items: 1)
# - [20489] ESC-auto-andromeda-ip (ip, items: 2)
# - [19676] ESC-auto-stealc-ip (ip, items: 87)
# - [19688] ESC-auto-qbot-ip (ip, items: 386)
# - [20675] ESC-auto-clop-ip (ip, items: 2)
# - [11473] ET_alert_rules_Ave_Maria (dn, items: 1)
# - [19698] ESC-auto-virut-dns (dn, items: 1)
# - [20612] ESC-auto-neshta-dns (dn, items: 1)
# - [4153] ESC-auto-amadey-dns (dn, items: 77)
# - [11475] ET_alert_rules_EvilGrab (dn, items: 1)
# - [23039] ESC-auto-apt36-dns (dn, items: 1)
# - [11476] ET_alert_rules_MirrorThief (dn, items: 2)
# - [11477] ET_alert_rules_Stately (dn, items: 1)
# - [23880] ESC-auto-locky-dns (dn, items: 1)
# - [11479] ET_alert_rules_Loli (dn, items: 1)
# - [20357] ESC-manual-gocovenant-dns (dn, items: 3)
# - [22324] ESC-auto-waketagat-dns (dn, items: 1)
# - [21023] ESC-auto-powershower-dns (dn, items: 2)
# - [19702] ESC-auto-zeuspanda-dns (dn, items: 1)
# - [11480] ET_alert_rules_FerociousKitten (dn, items: 2)
# - [20833] ESC-auto-rhadamanthys-dns (dn, items: 14)
# - [21870] ESC-auto-revil-dns (dn, items: 10)
# - [20458] ESC-auto-moobot-dns (dn, items: 10)
# - [11540] ET_alert_rules_OilRig (dn, items: 3)
# - [19728] ESC-auto-orcus_rat-dns (dn, items: 2)
# - [22060] ESC-auto-sys01-dns (dn, items: 7)
# - [11541] ET_alert_rules_unrecognisable_malware_domainlist (dn, items: 59)
# - [25135] ESC-auto-latrodectus-dns (dn, items: 17)
# - [23053] ESC-manual-konni-dns (dn, items: 23)
# - [23587] ESC-auto-valak-dns (dn, items: 1)
# - [11542] ET_alert_rules_TransparentTribe (dn, items: 4)
# - [23054] ESC-manual-iph1psvcbackdoor-dns (dn, items: 1)
# - [14922] ET_alert_rules_Kamran (dn, items: 1)
# - [11545] ET_alert_rules_Inception (dn, items: 3)
# - [23056] ESC-manual-kazn-dns (dn, items: 2)
# - [11546] ET_alert_rules_SideCopy (dn, items: 5)
# - [25120] ESC-auto-oceanlotus-dns (dn, items: 1)
# - [19663] ESC-auto-purecrypter-ip (ip, items: 4)
# - [20318] ESC-manual-sliver-ip (ip, items: 2)
# - [19926] ESC-manual-werewolves-ip (ip, items: 1)
# - [4139] ESC-auto-bitrat-ip (ip, items: 4)
# - [19012] ESC-manual-phantomcore-ip (ip, items: 9)
# - [19014] ESC-auto-lockbit-ip (ip, items: 5)
# - [4346] ESC-manual-apt35-ip (ip, items: 13)
# - [21018] ESC-auto-orcus_rat-ip (ip, items: 18)
# - [21021] ESC-auto-mass_logger-ip (ip, items: 1)
# - [15438] ET_alert_rules_Magnet (dn, items: 7)
# - [20496] ESC-auto-blacknet_rat-dns (dn, items: 4)
# - [20862] ESC-manual-dwarf_werewolf-dns (dn, items: 11)
# - [20786] ESC-auto-zeusbot-dns (dn, items: 2)
# - [23437] ESC-auto-gold_prelude-dns (dn, items: 4)
# - [11499] ET_alert_rules_DonotGroup (dn, items: 38)
# - [11500] ET_alert_rules_TURNEDUP (dn, items: 5)
# - [11523] ET_alert_rules_APT_C_23 (dn, items: 159)
# - [14920] ET_alert_rules_JS (dn, items: 1)
# - [19719] ESC-auto-sakula_rat-dns (dn, items: 4)
# - [11528] ET_alert_rules_MechaFlounder (dn, items: 2)
# - [4406] ESC-manual-xdspy-dns (dn, items: 18)
# - [11529] ET_alert_rules_Toneshell (dn, items: 1)
# - [11548] ET_alert_rules_APT10 (dn, items: 8)
# - [11549] ET_alert_rules_Trojan_Ransom (dn, items: 2)
# - [11550] ET_alert_rules_DeathStalker (dn, items: 3)
# - [11551] ET_alert_rules_Phorpiex (dn, items: 63)
# - [11553] ET_alert_rules_Mirai_shiina (dn, items: 1)
# - [11555] ET_alert_rules_Inter_Skimmer (dn, items: 5)
# - [11556] ET_alert_rules_Group21 (dn, items: 1)
# - [11557] ET_alert_rules_Harly_AO (dn, items: 1)
# - [19735] ESC-auto-redline_stealer-dns (dn, items: 154)
# - [11558] ET_alert_rules_GravityRAT (dn, items: 29)
# - [11559] ET_alert_rules_NSO (dn, items: 15)
# - [11560] ET_alert_rules_Arid_Viper (dn, items: 18)
# - [20877] ESC-manual-follina-dns (dn, items: 2)
# - [11562] ET_alert_rules_ThiefQuest (dn, items: 1)
# - [20469] ESC-auto-meterpreter-ip (ip, items: 3)
# - [20555] ESC-auto-zgrat-ip (ip, items: 1)
# - [20668] ESC-auto-tellyouthepass-ip (ip, items: 1)
# - [19695] ESC-auto-quasar_rat-ip (ip, items: 261)
# - [23041] ESC-auto-other-dns (dn, items: 127)
# - [11481] ET_alert_rules_ToddyCat (dn, items: 1)
# - [22325] ESC-auto-babuk-dns (dn, items: 5)
# - [23042] ESC-manual-bluelotus-dns (dn, items: 1)
# - [11483] ET_alert_rules_Rekoobe (dn, items: 1)
# - [12404] ET_alert_rules_Khepri (dn, items: 11)
# - [22906] ESC-auto-cryptbot-dns (dn, items: 757)
# - [11501] ET_alert_rules_Donot (dn, items: 1)
# - [23139] ESC-auto-bancos-dns (dn, items: 1)
# - [4395] ESC-manual-woody-dns (dn, items: 26)
# - [20369] ESC-manual-redfoxtrot-dns (dn, items: 104)
# - [11508] ET_alert_rules_ChamelGang (dn, items: 5)
# - [11530] ET_alert_rules_Desert_Falcon (dn, items: 10)
# - [11531] ET_alert_rules_Konni (dn, items: 3)
# - [23050] ESC-manual-tvrat-dns (dn, items: 1)
# - [20872] ESC-manual-safer-dns (dn, items: 3)
# - [22059] ESC-auto-disco-dns (dn, items: 1)
# - [20873] ESC-manual-maldownloader-dns (dn, items: 2)
# - [19983] ET_alert_rules_Iluria (dn, items: 2)
# - [11563] ET_alert_rules_Rovnix (dn, items: 1)
# - [15444] ET_alert_rules_DinodasRAT (dn, items: 2)
# - [11564] ET_alert_rules_DeadlyKiss (dn, items: 2)
# - [25081] ESC-auto-balada_injector-dns (dn, items: 12)
# - [23058] ESC-auto-dev-0960-dns (dn, items: 1)
# - [25175] ESC-auto-blind_eagle-dns (dn, items: 3)
# - [11568] ET_alert_rules_Patchwork (dn, items: 5)
# - [22333] ESC-auto-metastealer-dns (dn, items: 3)
# - [11574] ET_alert_rules_Hermit (dn, items: 17)
# - [2600] ESC-auto-lockbit-dns (dn, items: 2)
# - [25230] ESC-auto-parrot_tds-dns (dn, items: 1)
# - [20649] ESC-auto-venom_rat-ip (ip, items: 3)
# - [19657] ESC-auto-ave_maria-ip (ip, items: 20)
# - [2173] ESC-auto-njrat-ip (ip, items: 46)
# - [20158] ESC-auto-donut_injector-ip (ip, items: 3)
# - [21384] ESC-manual-calypso-ip (ip, items: 2)
# - [20319] ESC-manual-facefish-ip (ip, items: 3)
# - [20923] ESC-manual-shadowpad-ip (ip, items: 2)
# - [2410] ESC-auto-doubleback-ip (ip, items: 10)
# - [439] ESC-MSF-exploits-md5 (md5, items: 14)
# - [11484] ET_alert_rules_PREDATOR (dn, items: 226)
# - [11485] ET_alert_rules_MysterySnail (dn, items: 1)
# - [11486] ET_alert_rules_Eternity (dn, items: 2)
# - [11487] ET_alert_rules_Lemon_Duck (dn, items: 12)
# - [23043] ESC-manual-avemaria-dns (dn, items: 1)
# - [19892] ESC-manual-cloud_atlas-dns (dn, items: 98)
# - [20865] ESC-manual-learningers-dns (dn, items: 2)
# - [19712] ESC-auto-stealc-dns (dn, items: 9)
# - [20866] ESC-manual-taxoff-dns (dn, items: 1)
# - [22525] ESC-auto-ducktail-dns (dn, items: 1)
# - [20596] ESC-auto-fakeupdates-dns (dn, items: 259)
# - [11504] ET_alert_rules_CASHY200 (dn, items: 4)
# - [21404] ESC-auto-mydoom-dns (dn, items: 6)
# - [19981] ET_alert_rules_APT42 (dn, items: 14)
# - [20371] ESC-manual-chamelgang-dns (dn, items: 5)
# - [20372] ESC-manual-xworm-dns (dn, items: 1)
# - [11521] ET_alert_rules_domains_dotprefix (dn, items: 841)
# - [11525] ET_alert_rules_Fabookie (dn, items: 1)
# - [11526] ET_alert_rules_PoetRat (dn, items: 1)
# - [11527] ET_alert_rules_Lazarus (dn, items: 28)
# - [22475] ESC-auto-schtasks-dns (dn, items: 1)
# - [22330] ESC-auto-entropy-dns (dn, items: 1)
# - [20719] ESC-auto-mispadu-dns (dn, items: 2)
# - [25182] ESC-auto-fin8-dns (dn, items: 1)
# - [26093] ESC-auto-turla_group-dns (dn, items: 2)
# - [23809] ESC-auto-ramnit-dns (dn, items: 3)
# - [25487] ESC-auto-warmcookie-dns (dn, items: 1)
# - [20594] ESC-auto-netwire-ip (ip, items: 6)
# - [20666] ESC-auto-deimosc2-ip (ip, items: 1)
# - [21391] ESC-manual-mirai-ip (ip, items: 1)
# - [19686] ESC-auto-ghost_rat-ip (ip, items: 18)
# - [20855] ESC-manual-phishing-ip (ip, items: 1)
# - [20677] ESC-auto-collectorgoomba-ip (ip, items: 1)
# - [21178] ESC-auto-hawkeye_keylogger-ip (ip, items: 3)
# - [20678] ESC-auto-glupteba-ip (ip, items: 1)
# - [20355] ESC-manual-team46-dns (dn, items: 4)
# - [11488] ET_alert_rules_Gigabud (dn, items: 6)
# - [11489] ET_alert_rules_ProjectSauron (dn, items: 1)
# - [11490] ET_alert_rules_Keyboy (dn, items: 7)
# - [20789] ESC-auto-matanbuchus-dns (dn, items: 1)
# - [11491] ET_alert_rules_InnaputRAT (dn, items: 2)
# - [11492] ET_alert_rules_ViperSoftX (dn, items: 51)
# - [11495] ET_alert_rules_SHARPEXT (dn, items: 2)
# - [11496] ET_alert_rules_APT28 (dn, items: 93)
# - [11498] ET_alert_rules_APT32 (dn, items: 25)
# - [22396] ET_alert_rules_SideWinder (dn, items: 1)
# - [11505] ET_alert_rules_ComRAT (dn, items: 6)
# - [22329] ESC-auto-rusty_stealer-dns (dn, items: 1)
# - [11506] ET_alert_rules_Warzone (dn, items: 1)
# - [11507] ET_alert_rules_DCRat (dn, items: 3)
# - [20868] ESC-manual-ir-inc-unk-072024-dns (dn, items: 8)
# - [23044] ESC-manual-agentgroup-dns (dn, items: 2)
# - [23046] ESC-manual-bisonal-dns (dn, items: 4)
# - [23047] ESC-manual-sysupdate-dns (dn, items: 8)
# - [11520] ET_alert_rules_FamousSparrow (dn, items: 1)
# - [11522] ET_alert_rules_OSX (dn, items: 3)
# - [2536] ESC-auto-formbook-dns (dn, items: 167)
# - [15441] ET_alert_rules_FakeExt (dn, items: 8)
# - [19739] ESC-auto-fasolrat-dns (dn, items: 2)
# - [11570] ET_alert_rules_BLINDEAGLE (dn, items: 3)
# - [20892] ESC-manual-phantomshell-dns (dn, items: 4)
# - [24466] ESC-auto-makop_ransomware-dns (dn, items: 10)
# - [18896] ESC-auto-privateloader-ip (ip, items: 10)
# - [4765] ESC-auto-trickbot-ip (ip, items: 174)
# - [20660] ESC-auto-marcher-ip (ip, items: 4)
# - [2213] ESC-auto-sliver-ip (ip, items: 696)
# - [20779] ESC-auto-xmrig-ip (ip, items: 3)
# - [20330] ESC-auto-viper_rat-ip (ip, items: 22)
# - [20331] ESC-auto-bashlite-ip (ip, items: 229)
# - [20922] ESC-manual-ta428-ip (ip, items: 1)
# - [2334] ESC-auto-amadey-ip (ip, items: 131)
# - [2338] ESC-auto-asyncrat-ip (ip, items: 700)
# - [19690] ESC-auto-conti-ip (ip, items: 1)
# - [21336] ESC-auto-limerat-ip (ip, items: 1)
# - [794] tor-relays (ip, items: 15858)
# - [20493] ESC-auto-moobot-ip (ip, items: 19)
# - [22685] ESC-auto-bumblebee-ip (ip, items: 1)
# - [22633] ESC-manual-cryptersandtools-infra-ip (ip, items: 8)
# - [9897] unknown_APT_ip (ip, items: 15)
# - [24954] ESC-manual-backdoor-ip (ip, items: 1)
# - [11468] ET_alert_rules_POWERTON (dn, items: 1)
# - [11474] ET_alert_rules_Domino (dn, items: 1)
# - [11493] ET_alert_rules_S1deload (dn, items: 1)
# - [12406] ET_alert_rules_Allakore (dn, items: 6)
# - [19713] ESC-auto-ghost_rat-dns (dn, items: 33)
# - [19938] ESC-manual-fsswiper-dns (dn, items: 3)
# - [4910] ESC-auto-fabookie-dns (dn, items: 2)
# - [20365] ESC-manual-facefish-dns (dn, items: 7)
# - [11554] ET_alert_rules_APT_C_27 (dn, items: 6)
# - [25512] ESC-auto-vectorstealer-dns (dn, items: 1)
# - [25968] ESC-auto-guard-dns (dn, items: 8)
# - [21213] ESC-auto-shadowpad-dns (dn, items: 1)
# - [25737] ESC-auto-gandcrab-dns (dn, items: 1)
# - [25490] ESC-auto-sharkbot-dns (dn, items: 1)
# - [20414] ESC-manual-apt41-dns (dn, items: 88)
# - [11674] ET_alert_rules_DeltaStealer (dn, items: 3)
# - [20298] ESC-auto-revenge_rat-ip (ip, items: 1)
# - [19652] ESC-auto-sload-ip (ip, items: 2)
# - [20640] ESC-auto-doghousepower-ip (ip, items: 3)
# - [20481] ESC-auto-mozi-ip (ip, items: 56)
# - [21376] ESC-auto-n-w0rm-ip (ip, items: 1)
# - [21877] ESC-auto-phorpiex-ip (ip, items: 9)
# - [20482] ESC-auto-404_keylogger-ip (ip, items: 1)
# - [20918] ESC-auto-gozi-ip (ip, items: 2)
# - [20590] ESC-auto-loda-ip (ip, items: 2)
# - [20985] ESC-auto-xrat-ip (ip, items: 1)
# - [22084] ESC-manual-fluffywolf-ip (ip, items: 2)
# - [21818] ESC-manual-phaseshifters-ip (ip, items: 2)
# - [20645] ESC-auto-krbanker-ip (ip, items: 1)
# - [25859] ESC-auto-xorist-ip (ip, items: 1)
# - [20651] ESC-auto-sshdoor-ip (ip, items: 3)
# - [20652] ESC-auto-ermac-ip (ip, items: 11)
# - [20486] ESC-auto-laplasclipper-ip (ip, items: 3)
# - [19664] ESC-auto-redline_stealer-ip (ip, items: 468)
# - [20693] ESC-auto-dothetuk-ip (ip, items: 1)
# - [20538] ESC-auto-cryptbot-ip (ip, items: 2)
# - [20940] ESC-manual-kitsune-ip (ip, items: 1)
# - [20667] ESC-auto-titanstealer-ip (ip, items: 1)
# - [2331] ESC-auto-metasploit-ip (ip, items: 207)
# - [11494] ET_alert_rules_Smanager (dn, items: 2)
# - [20364] ESC-manual-shadowpad-dns (dn, items: 80)
# - [25863] ESC-auto-qjwmonkey-dns (dn, items: 1)
# - [12408] ET_alert_rules_Lumma (dn, items: 269)
# - [11143] cobalt_stager (dn, items: 1)
# - [17592] test_list (ip, items: 1)
# - [22335] ESC-auto-zonebac-dns (dn, items: 2)
# - [11577] ET_alert_rules_Bitter (dn, items: 7)
# - [24887] ESC-auto-lumma-dns (dn, items: 1261)
# - [23059] ESC-auto-winnti_group-dns (dn, items: 1)
# - [21125] ET_alert_rules_Mint (dn, items: 2)
# - [21846] ESC-auto-phorpiex-dns (dn, items: 63)
# - [25969] ESC-auto-javali-dns (dn, items: 3)
# - [11712] ET_alert_rules_Shlayer (dn, items: 10)
# - [11713] ET_alert_rules_China_APT (dn, items: 2)
# - [18906] ESC-auto-tofsee-ip (ip, items: 9)
# - [20487] ESC-auto-xworm-ip (ip, items: 3)
# - [19670] ESC-auto-agent_tesla-ip (ip, items: 54)
# - [20609] ESC-manual-apt43-ip (ip, items: 1)
# - [2230] ESC-auto-emotet-ip (ip, items: 682)
# - [19675] ESC-auto-cobalt_strike-ip (ip, items: 3731)
# - [21011] ESC-manual-malicious_scan-ip (ip, items: 1)
# - [20665] ESC-auto-gcleaner-ip (ip, items: 1)
# - [20339] ESC-auto-plugx-ip (ip, items: 52)
# - [22594] ESC-auto-risepro-ip (ip, items: 5)
# - [20350] ESC-auto-danabot-ip (ip, items: 14)
# - [20495] ESC-auto-mars-ip (ip, items: 1)
# - [22135] ESC-auto-ryuk-dns (dn, items: 1)
# - [11478] ET_alert_rules_Hisoka (dn, items: 1)
# - [19979] ET_alert_rules_ACR (dn, items: 13)
# - [11497] ET_alert_rules_PlayfulTaurus (dn, items: 1)
# - [11503] ET_alert_rules_HeaderTip (dn, items: 3)
# - [1434] ip_checkers (dn, items: 178)
# - [19985] ET_alert_rules_Amadey (dn, items: 1)
# - [23140] ESC-auto-fuery-dns (dn, items: 1)
# - [20384] ESC-manual-phantomcore-dns (dn, items: 4)
# - [23057] ESC-manual-scarcruft-dns (dn, items: 2)
# - [25084] ESC-auto-ostap-dns (dn, items: 26)
# - [25038] ESC-auto-suppobox-dns (dn, items: 2)
# - [22637] ESC-manual-cryptersandtools-infra-dns (dn, items: 9)
# - [11578] ET_alert_rules_TA401 (dn, items: 1)
# - [11579] ET_alert_rules_APT38 (dn, items: 2)
# - [11580] ET_alert_rules_POWERRATANKBA (dn, items: 2)
# - [11581] ET_alert_rules_Unknown_APT (dn, items: 2)
# - [25864] ESC-auto-mustang_panda-dns (dn, items: 1)
# - [25865] ESC-auto-recordbreaker-dns (dn, items: 1)
# - [25735] ESC-auto-redcurl-dns (dn, items: 1)
# - [25868] ESC-auto-strrat-dns (dn, items: 1)
# - [25738] ESC-auto-prysmax-dns (dn, items: 2)
# - [25957] ESC-auto-qrat-dns (dn, items: 1)
# - [23094] ESC-auto-bianlian-dns (dn, items: 1)
# - [20663] ESC-auto-mimikatz-ip (ip, items: 1)
# - [793] sinkholes (ip, items: 256)
# - [20491] ESC-auto-netsupport-ip (ip, items: 3)
# - [20671] ESC-auto-arkei-ip (ip, items: 2)
# - [20672] ESC-auto-spynote-ip (ip, items: 3)
# - [19037] ESC-auto-rhadamanthys-ip (ip, items: 28)
# - [20674] ESC-auto-recordbreaker-ip (ip, items: 1)
# - [11472] ET_alert_rules_Gh0st (dn, items: 2)
# - [20945] ESC-auto-raccoon-dns (dn, items: 7)
# - [20863] ESC-manual-phantomrat-dns (dn, items: 6)
# - [14917] ET_alert_rules_MacOS (dn, items: 1)
# - [22716] ESC-auto-loda-dns (dn, items: 4)
# - [19709] ESC-auto-revenge_rat-dns (dn, items: 3)
# - [11524] ET_alert_rules_Stonefly (dn, items: 2)
# - [20499] ESC-auto-meterpreter-dns (dn, items: 1)
# - [20876] ESC-manual-stealer-dns (dn, items: 1)
# - [8325] ESC-manual-excobalt-dns (dn, items: 106)
# - [21416] ESC-auto-nullmixer-dns (dn, items: 4)
# - [11569] ET_alert_rules_PowHeartBeat (dn, items: 2)
# - [11572] ET_alert_rules_Domen_SocEng (dn, items: 3)
# - [23060] ESC-manual-smoothoperator-dns (dn, items: 21)
# - [25085] ESC-auto-emmenhtal-dns (dn, items: 20)
# - [24082] ET_alert_rules_Panther (dn, items: 1)
# - [11582] ET_alert_rules_StrongPity (dn, items: 2)
# - [19747] ESC-auto-arkei-dns (dn, items: 8)
# - [19748] ESC-auto-gozi-dns (dn, items: 19)
# - [22338] ESC-auto-bumblebee-dns (dn, items: 4)
# - [11583] ET_alert_rules_POLONIUM (dn, items: 2)
# - [11584] ET_alert_rules_WebMonitor (dn, items: 2)
# - [24402] ESC-auto-purecrypter-dns (dn, items: 1)
# - [20798] ESC-auto-brute_ratel-dns (dn, items: 4)
# - [11585] ET_alert_rules_PirateMatryoshka (dn, items: 1)
# - [11586] ET_alert_rules_Plurox (dn, items: 2)
# - [12417] ET_alert_rules_Sharp (dn, items: 1)
# - [11588] ET_alert_rules_ShellCrew (dn, items: 27)
# - [25870] ESC-auto-banload-dns (dn, items: 3)
# - [25140] ESC-auto-sectoprat-dns (dn, items: 1)
# - [20186] ESC-auto-lokibot-ip (ip, items: 15)
# - [20351] ESC-auto-havoc-ip (ip, items: 55)
# - [22473] ESC-auto-seraph-dns (dn, items: 1)
# - [11482] ET_alert_rules_Chaos_Botnet (dn, items: 6)
# - [21114] ET_alert_rules_Spyder (dn, items: 1)
# - [20867] ESC-manual-operation_triangulation-dns (dn, items: 15)
# - [11502] ET_alert_rules_Maldoc (dn, items: 3)
# - [20793] ESC-auto-krbanker-dns (dn, items: 3)
# - [20379] ESC-manual-gamaredon-dns (dn, items: 1)
# - [11543] ET_alert_rules_TROJAN_OSX_Keydnap (dn, items: 2)
# - [11544] ET_alert_rules_LuaDream (dn, items: 2)
# - [20558] ESC-auto-bandook-dns (dn, items: 2)
# - [22454] ESC-auto-mekotio-dns (dn, items: 4)
# - [11575] ET_alert_rules_eleethub (dn, items: 2)
# - [19744] ESC-auto-agent_tesla-dns (dn, items: 49)
# - [21419] ESC-auto-megumin-dns (dn, items: 1)
# - [20503] ESC-auto-applejeus-dns (dn, items: 3)
# - [20290] ESC-auto-conti-dns (dn, items: 5)
# - [11587] ET_alert_rules_Xbash (dn, items: 7)
# - [19922] ESC-auto-clipbanker-dns (dn, items: 9)
# - [11589] ET_alert_rules_Beapy (dn, items: 2)
# - [11592] ET_alert_rules_APT34 (dn, items: 1)
# - [25179] ESC-auto-vermin-dns (dn, items: 1)
# - [11605] ET_alert_rules_Matanbuchus (dn, items: 1)
# - [20803] ESC-auto-systembc-dns (dn, items: 39)
# - [19766] ESC-auto-gcleaner-dns (dn, items: 3)
# - [4206] ESC-auto-njrat-dns (dn, items: 54)
# - [25180] ESC-auto-xenorat-dns (dn, items: 1)
# - [11608] ET_alert_rules_LYCEUM (dn, items: 27)
# - [11609] ET_alert_rules_Backdoor (dn, items: 3)
# - [20888] ESC-manual-broforce-dns (dn, items: 6)
# - [11619] ET_alert_rules_Raspberry (dn, items: 1)
# - [20889] ESC-manual-fas_phishing-dns (dn, items: 10)
# - [21127] ET_alert_rules_ClearFake (dn, items: 2)
# - [11714] ET_alert_rules_APT29 (dn, items: 4)
# - [21073] ESC-auto-spynote-dns (dn, items: 18)
# - [20498] ESC-auto-crimson-dns (dn, items: 10)
# - [20377] ESC-manual-buhtrap-dns (dn, items: 4)
# - [21414] ESC-auto-darkcloud_stealer-dns (dn, items: 2)
# - [20746] ESC-auto-upatre-dns (dn, items: 28)
# - [20252] ESC-auto-lemon_duck-dns (dn, items: 2)
# - [21117] ET_alert_rules_BMANAGER (dn, items: 6)
# - [11594] ET_alert_rules_TwistedPanda (dn, items: 4)
# - [20506] ESC-auto-magecart-dns (dn, items: 3)
# - [8910] ESC-manual-werewolves-dns (dn, items: 4)
# - [11598] ET_alert_rules_ProcessRequest (dn, items: 1)
# - [11599] ET_alert_rules_Cryptominer (dn, items: 1)
# - [11600] ET_alert_rules_oRAT (dn, items: 1)
# - [20747] ESC-auto-xegumumune-dns (dn, items: 1)
# - [22401] ET_alert_rules_Xworm (dn, items: 1)
# - [20586] ESC-auto-tiggre-dns (dn, items: 3)
# - [20884] ESC-manual-goffee-dns (dn, items: 25)
# - [11601] ET_alert_rules_CHIMNEYSWEEP (dn, items: 10)
# - [22342] ESC-auto-mars-dns (dn, items: 1)
# - [11602] ET_alert_rules_IcedID (dn, items: 105)
# - [17709] ET_alert_rules_Malicious (dn, items: 1)
# - [11603] ET_alert_rules_Spy_Banker_BTO (dn, items: 1)
# - [23577] ESC-manual-tuna-ru-tunnels-dns (dn, items: 1)
# - [23063] ESC-manual-lockbit-dns (dn, items: 1)
# - [20399] ESC-auto-perlbot-dns (dn, items: 1)
# - [11610] ET_alert_rules_WinGo (dn, items: 1)
# - [11611] ET_alert_rules_DroidKungFu (dn, items: 1)
# - [25109] ESC-auto-ransomhub-dns (dn, items: 4)
# - [11612] ET_alert_rules_PHPStudy (dn, items: 1)
# - [19948] ESC-manual-ta558-dns (dn, items: 1)
# - [24980] ESC-auto-flawedammyy-dns (dn, items: 1)
# - [11614] ET_alert_rules_TAIDOOR (dn, items: 2)
# - [25110] ESC-auto-supershell-dns (dn, items: 1)
# - [25040] ESC-auto-gh0stcringe-dns (dn, items: 1)
# - [4455] ESC-auto-smokeloader-dns (dn, items: 35)
# - [11620] ET_alert_rules_Bahamut (dn, items: 1)
# - [25239] ESC-auto-comet-dns (dn, items: 1)
# - [19734] ESC-auto-qbot-dns (dn, items: 50)
# - [19736] ESC-auto-dbatloader-dns (dn, items: 1)
# - [11561] ET_alert_rules_NukeSped (dn, items: 3)
# - [14924] ET_alert_rules_Comebacker (dn, items: 3)
# - [11566] ET_alert_rules_CustomRAT (dn, items: 1)
# - [11567] ET_alert_rules_ConfuciousAPT (dn, items: 2)
# - [20880] ESC-auto-plugx-dns (dn, items: 8)
# - [20271] ESC-auto-404_keylogger-dns (dn, items: 6)
# - [11604] ET_alert_rules_Satori (dn, items: 3)
# - [4207] ESC-auto-mirai-dns (dn, items: 274)
# - [11606] ET_alert_rules_TAG28 (dn, items: 5)
# - [20718] ESC-auto-blindingcan-dns (dn, items: 1)
# - [2628] ESC-auto-emotet-dns (dn, items: 412)
# - [20887] ESC-manual-dns_canary-dns (dn, items: 142)
# - [11613] ET_alert_rules_Wintervivern (dn, items: 4)
# - [11615] ET_alert_rules_Tandem_Espionage (dn, items: 12)
# - [20509] ESC-auto-hawkeye_keylogger-dns (dn, items: 3)
# - [11616] ET_alert_rules_Ramsay (dn, items: 2)
# - [11617] ET_alert_rules_PhantomNet (dn, items: 2)
# - [23066] ESC-manual-blacktie-dns (dn, items: 3)
# - [21836] ESC-auto-reverserat-dns (dn, items: 1)
# - [24643] ESC-auto-prometei-dns (dn, items: 669)
# - [11621] ET_alert_rules_ursnif (dn, items: 9)
# - [21427] ESC-auto-allakore-dns (dn, items: 1)
# - [17710] ET_alert_rules_MuddyWater (dn, items: 1)
# - [11622] ET_alert_rules_ShadowPad (dn, items: 2)
# - [23095] ESC-auto-apt43-dns (dn, items: 4)
# - [2748] ESC-auto-bitrat-dns (dn, items: 2)
# - [26027] ESC-auto-anchormail-dns (dn, items: 1)
# - [26077] ESC-auto-strelastealer-dns (dn, items: 1)
# - [24086] ET_alert_rules_DeerStealer (dn, items: 17)
# - [11720] ET_alert_rules_Varenyky (dn, items: 9)
# - [25768] ESC-auto-mintstealer-ip (ip, items: 1)
# - [25646] ET_alert_rules_CeranaKeeper (dn, items: 3)
# - [25770] ESC-auto-jss_loader-dns (dn, items: 1)
# - [11509] ET_alert_rules_Phishing (dn, items: 16)
# - [11510] ET_alert_rules_Sofacy (dn, items: 1)
# - [11511] ET_alert_rules_DarkGate (dn, items: 1)
# - [11512] ET_alert_rules_APT_NGO_wuaclt (dn, items: 3)
# - [17706] ET_alert_rules_WaveStealer (dn, items: 2)
# - [20870] ESC-manual-phishing-dns (dn, items: 14)
# - [11513] ET_alert_rules_lumma (dn, items: 2)
# - [19982] ESC-auto-netsupportrat-dns (dn, items: 45)
# - [11514] ET_alert_rules_OceanLotus (dn, items: 3)
# - [21339] ESC-auto-donut_injector-dns (dn, items: 3)
# - [11515] ET_alert_rules_Qadars (dn, items: 3)
# - [11516] ET_alert_rules_Candiru (dn, items: 3)
# - [20374] ESC-manual-ta428-dns (dn, items: 2)
# - [19716] ESC-auto-findpos-dns (dn, items: 19)
# - [23045] ESC-auto-excobalt-dns (dn, items: 3)
# - [11517] ET_alert_rules_Cryptbot (dn, items: 3)
# - [11518] ET_alert_rules_Delf_TJJ (dn, items: 10)
# - [20791] ESC-auto-boxter-dns (dn, items: 1)
# - [20871] ESC-manual-ir-inc-unk-081524-dns (dn, items: 7)
# - [21240] ESC-auto-alina_pos-dns (dn, items: 2)
# - [11519] ET_alert_rules_Karkoff (dn, items: 3)
# - [25649] ET_alert_rules_directlinkgen_bot (dn, items: 1)
# - [25650] ESC-auto-privateloader-dns (dn, items: 1)
# - [20390] ESC-manual-rmrf_group-dns (dn, items: 16)
# - [20392] ESC-manual-sliver-dns (dn, items: 3)
# - [11571] ET_alert_rules_TA453 (dn, items: 3)
# - [23062] ESC-manual-hive0117-dns (dn, items: 1)
# - [4198] ESC-auto-doubleback-dns (dn, items: 19)
# - [25772] ESC-auto-carbanak-dns (dn, items: 81)
# - [25679] ESC-manual-rms-ip (ip, items: 1)
# - [25681] ESC-auto-blacksuit-ip (ip, items: 1)
# - [25494] ESC-auto-solarmarker-dns (dn, items: 2)
# - [25495] ESC-auto-irata-dns (dn, items: 31)
# - [25496] ESC-auto-mirage-dns (dn, items: 2)
# - [11573] ET_alert_rules_DragonFly (dn, items: 2)
# - [23133] unknown_apt_022025_dns (dn, items: 4)
# - [20879] ESC-manual-radio_hacker-dns (dn, items: 2)
# - [11595] ET_alert_rules_Kimsuky (dn, items: 6)
# - [14926] ET_alert_rules_ELF (dn, items: 11)
# - [4442] ESC-manual-apt35-dns (dn, items: 234)
# - [20444] ESC-auto-wannacry-dns (dn, items: 23)
# - [21424] ESC-auto-simda-dns (dn, items: 68)
# - [25274] ESC-auto-rapid-dns (dn, items: 2)
# - [11618] ET_alert_rules_FIN8 (dn, items: 18)
# - [15448] ET_alert_rules_EvasivePanda (dn, items: 1)
# - [24105] ESC-manual-cobint-dns (dn, items: 1)
# - [20274] ESC-auto-unruy-dns (dn, items: 1)
# - [25653] ET_alert_rules_SnipBot (dn, items: 17)
# - [12419] ET_alert_rules_TrollAgent (dn, items: 4)
# - [22405] ET_alert_rules_Zloader (dn, items: 8)
# - [25774] ESC-auto-expiro-dns (dn, items: 1)
# - [25187] ESC-auto-mythic_c2-dns (dn, items: 3)
# - [25189] ESC-auto-bluesky-dns (dn, items: 1)
# - [25777] ESC-auto-fin7-dns (dn, items: 5)
# - [24384] ESC-auto-spyder-dns (dn, items: 1)
# - [24358] ESC-auto-anubis_stealer-dns (dn, items: 16)
# - [25091] ESC-auto-clearfake-dns (dn, items: 165)
# - [25288] ESC-auto-bundestrojaner-dns (dn, items: 1)
# - [25092] ESC-auto-konni-dns (dn, items: 8)
# - [11706] ET_alert_rules_Glupteba (dn, items: 13)
# - [21187] ESC-auto-play-dns (dn, items: 1)
# - [23093] ESC-manual-fasolrat-dns (dn, items: 2)
# - [11707] ET_alert_rules_Ransomware (dn, items: 3)
# - [21030] ESC-auto-volgmer-dns (dn, items: 1)
# - [20272] ESC-auto-shiz-dns (dn, items: 7)
# - [24723] ESC-auto-kinsing-dns (dn, items: 1)
# - [21835] ESC-auto-strictor-dns (dn, items: 1)
# - [11607] ET_alert_rules_mallox (dn, items: 1)
# - [14927] ET_alert_rules_TA430 (dn, items: 1)
# - [21425] ESC-auto-koceg-dns (dn, items: 1)
# - [20890] ESC-manual-bitrix_malware-dns (dn, items: 6)
# - [22404] ET_alert_rules_Remcos (dn, items: 1)
# - [19771] ESC-auto-smoothoperator-dns (dn, items: 5)
# - [19992] ET_alert_rules_Starry (dn, items: 2)
# - [19950] ESC-manual-iamtheking-dns (dn, items: 114)
# - [20511] ESC-auto-roaming_mantis-dns (dn, items: 1)
# - [25181] ESC-auto-rustdoor-dns (dn, items: 1)
# - [11623] ET_alert_rules_HadesAPT (dn, items: 1)
# - [11624] ET_alert_rules_Rshell (dn, items: 3)
# - [23069] ESC-manual-scalywolf-dns (dn, items: 1)
# - [11626] ET_alert_rules_Zeus (dn, items: 1)
# - [11627] ET_alert_rules_MICROPSIA (dn, items: 10)
# - [22344] ESC-auto-gamania-dns (dn, items: 1)
# - [11628] ET_alert_rules_DarkSide (dn, items: 2)
# - [23070] ESC-manual-core_werewolf-dns (dn, items: 2)
# - [11629] ET_alert_rules_TA402 (dn, items: 2)
# - [25447] ESC-auto-spaceship-dns (dn, items: 1)
# - [25149] ESC-auto-phantomrat-dns (dn, items: 1)
# - [25070] ESC-auto-beacon-dns (dn, items: 9)
# - [25668] ESC-auto-saitama_backdoor-dns (dn, items: 4)
# - [23080] ESC-manual-fakemsupdatestealer-dns (dn, items: 1)
# - [20422] ESC-auto-fatalrat-dns (dn, items: 2)
# - [25335] ESC-auto-coralraider-dns (dn, items: 1)
# - [26105] ESC-auto-cobalt_spider-dns (dn, items: 19)
# - [26106] ESC-manual-netrunnergolangstealer-dns (dn, items: 2)
# - [11625] ET_alert_rules_MageCart (dn, items: 28)
# - [11630] ET_alert_rules_Trojan_Banker (dn, items: 6)
# - [20893] ESC-manual-lifting_zmiy-dns (dn, items: 3)
# - [20404] ESC-manual-netsupportrat-dns (dn, items: 5)
# - [4215] ESC-auto-vidar-dns (dn, items: 170)
# - [11631] ET_alert_rules_CapraRAT (dn, items: 3)
# - [19774] ESC-auto-pupy-dns (dn, items: 4)
# - [21428] ESC-auto-pikabot-dns (dn, items: 5)
# - [11632] ET_alert_rules_Emptiness (dn, items: 8)
# - [11633] ET_alert_rules_Chafer (dn, items: 3)
# - [20406] ESC-manual-lnksvilli-dns (dn, items: 17)
# - [11634] ET_alert_rules_MINEBRIDGE (dn, items: 13)
# - [11635] ET_alert_rules_DNSpionage (dn, items: 1)
# - [11636] ET_alert_rules_SuperhardCorp (dn, items: 8)
# - [11637] ET_alert_rules_Trojan_Dropper (dn, items: 1)
# - [23072] ESC-manual-kimsuky-dns (dn, items: 2)
# - [11638] ET_alert_rules_Dorv (dn, items: 1)
# - [11639] ET_alert_rules_Metador (dn, items: 1)
# - [22911] ESC-auto-yanluowang-dns (dn, items: 1)
# - [11640] ET_alert_rules_APT41 (dn, items: 5)
# - [23073] ESC-auto-apt-c-07-dns (dn, items: 1)
# - [23074] ESC-manual-mirat-dns (dn, items: 1)
# - [11641] ET_alert_rules_Nightscout (dn, items: 3)
# - [22701] ESC-manual-mimistick-dns (dn, items: 7)
# - [21167] ESC-auto-flame-dns (dn, items: 1)
# - [20132] ESC-auto-athenago-dns (dn, items: 4)
# - [20409] ESC-manual-plugx-dns (dn, items: 5)
# - [795] miners (dn, items: 778)
# - [23075] ESC-manual-tinyshell-dns (dn, items: 2)
# - [11642] ET_alert_rules_Diezen (dn, items: 4)
# - [20046] ESC-auto-metasploit-dns (dn, items: 3)
# - [4223] ESC-auto-dcrat-dns (dn, items: 333)
# - [22409] ET_alert_rules_ZharkBOT (dn, items: 2)
# - [25499] ESC-auto-mykings_spreader-dns (dn, items: 3)
# - [11643] ET_alert_rules_Spy_Vultur_A (dn, items: 1)
# - [20896] ESC-auto-tiger_rat-dns (dn, items: 1)
# - [23077] ESC-auto-stargazer_goblin-dns (dn, items: 1)
# - [20897] ESC-manual-orca-dns (dn, items: 2)
# - [22347] ESC-auto-coper-dns (dn, items: 2)
# - [11644] ET_alert_rules_Trojan_Spy (dn, items: 2)
# - [20807] ESC-auto-black_basta-dns (dn, items: 7)
# - [11646] ET_alert_rules_BrushaLoader (dn, items: 28)
# - [11647] ET_alert_rules_SprySOCKS (dn, items: 2)
# - [22999] ESC-auto-spectre_rat-dns (dn, items: 9)
# - [11648] ET_alert_rules_Shuckworm (dn, items: 1)
# - [11649] ET_alert_rules_Spy_Banker_BOF (dn, items: 1)
# - [11650] ET_alert_rules_Bisonal (dn, items: 1)
# - [23078] ESC-manual-corewerewolf-dns (dn, items: 6)
# - [20808] ESC-auto-xworm-dns (dn, items: 7)
# - [11651] ET_alert_rules_ChromeLoader (dn, items: 1)
# - [11664] ET_alert_rules_Adware (dn, items: 3)
# - [20900] ESC-manual-russia_owa_phishing-dns (dn, items: 18)
# - [20906] ESC-manual-sspidoor-dns (dn, items: 2)
# - [25492] ESC-auto-ailurophile_stealer-dns (dn, items: 2)
# - [11708] ET_alert_rules_DNSChanger (dn, items: 5)
# - [12426] ET_alert_rules_KrustyLoader (dn, items: 11)
# - [11709] ET_alert_rules_Thallium (dn, items: 1)
# - [11710] ET_alert_rules_Spy_SmsSpy_XC (dn, items: 1)
# - [11711] ET_alert_rules_CoinMiner_ESJ_tr (dn, items: 6)
# - [20425] ESC-manual-calypso-dns (dn, items: 105)
# - [24308] ESC-auto-mamba-dns (dn, items: 1)
# - [26114] ESC-auto-bl00dy-ip (ip, items: 1)
# - [25543] ESC-auto-black_basta-ip (ip, items: 1)
# - [25545] ESC-auto-muddywater-ip (ip, items: 1)
# - [26116] ESC-manual-hudoor-ip (ip, items: 1)
# - [26121] ESC-manual-team46-ip (ip, items: 1)
# - [26122] ESC-auto-irgc-dns (dn, items: 1)
# - [20881] ESC-manual-medusastealer-dns (dn, items: 3)
# - [11590] ET_alert_rules_EvilNum (dn, items: 6)
# - [20801] ESC-auto-netsupport-dns (dn, items: 24)
# - [11596] ET_alert_rules_FIN7 (dn, items: 7)
# - [26126] ESC-manual-njrat-dns (dn, items: 1)
# - [20401] ESC-manual-formbook-dns (dn, items: 5)
# - [26127] ESC-auto-scamquerteo-dns (dn, items: 1)
# - [26120] ESC-auto-bl00dy-dns (dn, items: 2)
# - [11652] ET_alert_rules_Banker_Octo (dn, items: 16)
# - [11653] ET_alert_rules_Skimmer (dn, items: 1)
# - [19785] ESC-auto-bitter-dns (dn, items: 3)
# - [11654] ET_alert_rules_IRATA (dn, items: 2)
# - [11655] ET_alert_rules_sLoad (dn, items: 1)
# - [19993] ET_alert_rules_UNK_ConsoleCollie (dn, items: 3)
# - [25655] ET_alert_rules_NamelessC2 (dn, items: 1)
# - [19952] ESC-manual-dcrat-dns (dn, items: 1)
# - [25185] ESC-auto-fakebat-dns (dn, items: 1)
# - [11656] ET_alert_rules_FontOnLake (dn, items: 1)
# - [25090] ESC-auto-xfiles_stealer-dns (dn, items: 2)
# - [4224] ESC-auto-remcos-dns (dn, items: 139)
# - [24706] ESC-auto-smsthief-dns (dn, items: 1)
# - [11657] ET_alert_rules_ErbiumStealer (dn, items: 2)
# - [4225] ESC-auto-nanocore-dns (dn, items: 21)
# - [15449] ET_alert_rules_RedCurl (dn, items: 3)
# - [20574] ESC-auto-buer-dns (dn, items: 1)
# - [11658] ET_alert_rules_JEUSD (dn, items: 9)
# - [11659] ET_alert_rules_LegionLoader (dn, items: 1)
# - [24544] ESC-auto-lazagne-dns (dn, items: 1)
# - [11660] ET_alert_rules_Spy_Agent_AKS (dn, items: 1)
# - [19901] ESC-manual-fluffywolf-dns (dn, items: 28)
# - [11661] ET_alert_rules_APT33 (dn, items: 28)
# - [5198] ESC-manual-hellhounds-dns (dn, items: 22)
# - [20809] ESC-auto-darkradiation-dns (dn, items: 3)
# - [20810] ESC-auto-amos_stealer-dns (dn, items: 21)
# - [23121] ESC-auto-machete-dns (dn, items: 1)
# - [20899] ESC-manual-loader-dns (dn, items: 1)
# - [11662] ET_alert_rules_MagicRAT (dn, items: 1)
# - [21121] ET_alert_rules_Tnaket (dn, items: 1)
# - [25112] ESC-auto-darkgate-dns (dn, items: 1)
# - [11665] ET_alert_rules_Flooder_Agent_NAS (dn, items: 1)
# - [11666] ET_alert_rules_Nobelium (dn, items: 5)
# - [5013] ESC-auto-evilnum-dns (dn, items: 13)
# - [25275] ESC-auto-feodo-dns (dn, items: 1)
# - [19789] ESC-auto-koadic-dns (dn, items: 2)
# - [20412] ESC-auto-trickbot-dns (dn, items: 11)
# - [25054] ESC-auto-nitol-dns (dn, items: 1)
# - [11667] ET_alert_rules_PowerGhost (dn, items: 2)
# - [11668] ET_alert_rules_TScookie (dn, items: 2)
# - [23603] ESC-auto-toneshell-dns (dn, items: 2)
# - [20901] ESC-auto-siennapurple-dns (dn, items: 3)
# - [25072] ESC-auto-fareit-dns (dn, items: 3)
# - [20625] ESC-manual-apt31-dns (dn, items: 21)
# - [25656] ET_alert_rules_Librarian (dn, items: 1)
# - [23081] ESC-manual-lumma-dns (dn, items: 3)
# - [11670] ET_alert_rules_Unk_HeavensGate (dn, items: 5)
# - [11671] ET_alert_rules_CobaltStrike (dn, items: 28)
# - [21434] ESC-auto-tinba-dns (dn, items: 11)
# - [24778] ESC-auto-cobian_rat-dns (dn, items: 2)
# - [11672] ET_alert_rules_Pift (dn, items: 2)
# - [11673] ET_alert_rules_DustySky (dn, items: 2)
# - [25186] ESC-auto-acr_stealer-dns (dn, items: 4)
# - [23082] ESC-manual-revengerat-dns (dn, items: 1)
# - [23083] ESC-auto-lazarus_group-dns (dn, items: 2)
# - [4235] ESC-auto-netwire-dns (dn, items: 5)
# - [11675] ET_alert_rules_Spy_Bahamut_I (dn, items: 1)
# - [19795] ESC-auto-quasar_rat-dns (dn, items: 43)
# - [11676] ET_alert_rules_ActionLoader (dn, items: 7)
# - [11677] ET_alert_rules_TeamTNT (dn, items: 1)
# - [11678] ET_alert_rules_Trojan (dn, items: 15)
# - [11679] ET_alert_rules_Parallax (dn, items: 1)
# - [11680] ET_alert_rules_Sidewinder (dn, items: 118)
# - [11681] ET_alert_rules_ASNAROK (dn, items: 1)
# - [23084] ESC-manual-mustangpanda-dns (dn, items: 1)
# - [22307] ESC-auto-xrat-dns (dn, items: 3)
# - [17715] ET_alert_rules_Related (dn, items: 4)
# - [11686] ET_alert_rules_THREEBYTE (dn, items: 1)
# - [23086] ESC-manual-mikroceen-dns (dn, items: 3)
# - [11687] ET_alert_rules_Earth_Berberoka (dn, items: 1)
# - [11688] ET_alert_rules_HCRootkit (dn, items: 9)
# - [11689] ET_alert_rules_Darkme (dn, items: 8)
# - [19800] ESC-auto-bashlite-dns (dn, items: 4)
# - [11690] ET_alert_rules_YTY (dn, items: 4)
# - [20519] ESC-auto-regeorg-dns (dn, items: 1)
# - [19954] ESC-manual-remcos-dns (dn, items: 6)
# - [14930] ET_alert_rules_Ducktail (dn, items: 4)
# - [23087] ESC-auto-ta543-dns (dn, items: 1)
# - [19801] ESC-auto-pteranodon-dns (dn, items: 6)
# - [11691] ET_alert_rules_jssLoader (dn, items: 1)
# - [11692] ET_alert_rules_DarkHotel (dn, items: 3)
# - [23088] ESC-manual-sakula-dns (dn, items: 1)
# - [25555] ESC-manual-phaseshifters-dns (dn, items: 1)
# - [11682] ET_alert_rules_WoodyRAT (dn, items: 5)
# - [11683] ET_alert_rules_TontoTeam (dn, items: 6)
# - [11684] ET_alert_rules_Magniber (dn, items: 2)
# - [11685] ET_alert_rules_Exchange (dn, items: 1)
# - [20904] ESC-manual-blackfish-dns (dn, items: 4)
# - [20905] ESC-manual-outlookgrabber-dns (dn, items: 3)
# - [4241] ESC-manual-matadoor-dns (dn, items: 21)
# - [22645] ESC-manual-gh0stcringe-dns (dn, items: 1)
# - [19802] ESC-auto-cobalt_strike-dns (dn, items: 429)
# - [11693] ET_alert_rules_BAZAR (dn, items: 5)
# - [11694] ET_alert_rules_StolenPencil (dn, items: 14)
# - [11695] ET_alert_rules_Quasar (dn, items: 2)
# - [23089] ESC-manual-apt-c-36-dns (dn, items: 1)
# - [20587] ESC-auto-powerstats-dns (dn, items: 3)
# - [14931] ET_alert_rules_Flooder (dn, items: 1)
# - [5060] dynamic_dns (dn, items: 445)
# - [11696] ET_alert_rules_lu0bot (dn, items: 4)
# - [20418] ESC-manual-kitsune-dns (dn, items: 13)
# - [9898] unknown_APT_dns (dn, items: 5)
# - [11697] ET_alert_rules_Windshift (dn, items: 2)
# - [21844] ESC-auto-tinynuke-dns (dn, items: 2)
# - [14932] ET_alert_rules_GoldDigger (dn, items: 6)
# - [15450] ET_alert_rules_NGC2180 (dn, items: 1)
# - [11698] ET_alert_rules_Drinik (dn, items: 1)
# - [11699] ET_alert_rules_Unknown (dn, items: 1)
# - [21439] ESC-auto-vawtrak-dns (dn, items: 1)
# - [23090] ESC-auto-cloud_atlas-dns (dn, items: 2)
# - [11700] ET_alert_rules_DarkHydrus (dn, items: 28)
# - [11701] ET_alert_rules_TA455 (dn, items: 6)
# - [20907] ESC-manual-ru_critical_phishing-dns (dn, items: 15)
# - [20278] ESC-auto-monero_miner-dns (dn, items: 3)
# - [20420] ESC-manual-soundshell-dns (dn, items: 2)
# - [11702] ET_alert_rules_BatLoader (dn, items: 10)
# - [14933] ET_alert_rules_Xehook (dn, items: 2)
# - [20909] ESC-manual-finance_phishing_domains-dns (dn, items: 31)
# - [11703] ET_alert_rules_Epsilon (dn, items: 1)
# - [11704] ET_alert_rules_APT40 (dn, items: 9)
# - [11705] ET_alert_rules_DangerousPassword (dn, items: 2)
# - [23091] ESC-manual-microcin-dns (dn, items: 16)
# - [23152] ESC-manual-brockendoor-dns (dn, items: 1)
# - [11715] ET_alert_rules_Akira (dn, items: 1)
# - [21169] ESC-auto-babadeda-dns (dn, items: 1)
# - [19956] ESC-auto-tofsee-dns (dn, items: 9)
# - [4515] ESC-auto-azorult-dns (dn, items: 15)
# - [21796] ESC-manual-rarewolf-dns (dn, items: 11)
# - [20911] ESC-manual-cobalt-dns (dn, items: 4)
# - [22353] ESC-auto-beapy-dns (dn, items: 1)
# - [11716] ET_alert_rules_Final1stspy (dn, items: 1)
# - [23096] ESC-manual-huloader-dns (dn, items: 9)
# - [24290] ESC-manual-desert-dexter-iocs-dns (dn, items: 2)
# - [4516] ESC-auto-icedid-dns (dn, items: 165)
# - [21744] ESC-manual-gophish-dns (dn, items: 5)
# - [11717] ET_alert_rules_RouteX (dn, items: 10)
# - [19812] ESC-auto-danabot-dns (dn, items: 15)
# - [4654] ESC-manual-pseudogamaredon-dns (dn, items: 26)
# - [11718] ET_alert_rules_Anunak (dn, items: 9)
# - [11719] ET_alert_rules_Mirai (dn, items: 9)
# - [9593] ESC-manual-toddycat-dns (dn, items: 3)
# - [25657] ESC-auto-oilrig-dns (dn, items: 7)
# - [23097] ESC-manual-tiny_shell-dns (dn, items: 1)
# - [25056] ESC-auto-bazarbackdoor-dns (dn, items: 13)
# - [22543] ESC-auto-ginzo_stealer-dns (dn, items: 1)
# - [23098] ESC-auto-unc4393-dns (dn, items: 1)
# - [11721] ET_alert_rules_OriginLogger (dn, items: 4)
# - [11722] ET_alert_rules_GandCrab (dn, items: 3)
# - [11723] ET_alert_rules_Reborn (dn, items: 1)
# - [12124] ET_alert_rules_Koi (dn, items: 1)
# - [11724] ET_alert_rules_MosesStaff (dn, items: 1)
# - [4252] ESC-auto-asyncrat-dns (dn, items: 140)
# - [20431] ESC-manual-vintloader-dns (dn, items: 1)
# - [23099] ESC-manual-oilrig-dns (dn, items: 4)
# - [20952] ESC-manual-unknownandroidmalware-dns (dn, items: 4)
# - [22356] ESC-auto-iloveyou-dns (dn, items: 1)
# - [20913] ESC-manual-gsocket-dns (dn, items: 31)
# - [20914] ESC-auto-betabot-dns (dn, items: 1)
# - [21440] ESC-auto-artradownloader-dns (dn, items: 1)
# - [19817] ESC-auto-ermac-dns (dn, items: 73)
# - [11725] ET_alert_rules_Laplas (dn, items: 1)
# - [20915] ESC-manual-phishing_domains-dns (dn, items: 66)
# - [20916] ESC-manual-msaprdstbackdoor-dns (dn, items: 1)
# - [24872] ESC-manual-space_pirates-dns (dn, items: 700)
# - [21129] ET_alert_rules_Botnet (dn, items: 1)
# - [11726] ET_alert_rules_IIStealer (dn, items: 1)
# - [4521] ESC-auto-lokibot-dns (dn, items: 46)
# - [11727] ET_alert_rules_GobRAT (dn, items: 3)
# - [25268] ESC-auto-blackmatter-dns (dn, items: 3)
# - [24049] ESC-auto-venom_rat-dns (dn, items: 1)
# - [11728] ET_alert_rules_Gift_Cardshark (dn, items: 9)
# - [20917] ESC-manual-autoit_stealer-dns (dn, items: 9)

# %% [markdown]
# Поиск по ключевому слову

# %%
results = replists.get_lists(search="APT")

for r in results:
    print(f"{r['name']}")
# Out:
# ESC-auto-apt35-ip
# ESC-auto-apt28-ip
# ESC-auto-apt-c-09-dns
# ESC-auto-apt43-ip
# unknown_apt_031525_ip
# unknown_apt_022025_ip
# ESC-auto-apt35-dns
# ET_alert_rules_APT_C_48
# ESC-auto-apt36-dns
# ESC-manual-apt35-ip
# ET_alert_rules_APT_C_23
# ET_alert_rules_APT10
# ET_alert_rules_APT42
# ET_alert_rules_APT28
# ET_alert_rules_APT32
# unknown_APT_ip
# ET_alert_rules_APT_C_27
# ESC-manual-apt41-dns
# ET_alert_rules_China_APT
# ESC-manual-apt43-ip
# ET_alert_rules_APT38
# ET_alert_rules_Unknown_APT
# ET_alert_rules_APT34
# ET_alert_rules_APT29
# ET_alert_rules_ConfuciousAPT
# ESC-auto-apt43-dns
# ET_alert_rules_APT_NGO_wuaclt
# unknown_apt_022025_dns
# ESC-manual-apt35-dns
# ET_alert_rules_HadesAPT
# ET_alert_rules_APT41
# ESC-auto-apt-c-07-dns
# ET_alert_rules_APT33
# ESC-manual-apt31-dns
# ESC-manual-apt-c-36-dns
# unknown_APT_dns
# ET_alert_rules_APT40

# %% [markdown]
# Создание нового списка

# %%
new_list = replists.create_list(
    name="test_list_01",
    type="ip",
    color="1",
    description="Тестовый список IP-адресов",
    content="1.1.1.1\n2.2.2.2"
)
print(f"Список создан: {new_list['id']}")
# Out:
# Список создан: 26144

# %% [markdown]
# Обновление списка

# %%
updated = replists.update_list(list_id=new_list["id"], description="Обновлённый тестовый список IP-адресов")
print("Описание обновлено:", updated["description"])
# Out:
# Описание обновлено: Обновлённый тестовый список IP-адресов

# %% [markdown]
# Удаление списка

# %%
replists.delete_list(list_id=new_list["id"])
print("Список удалён")
# Out:
# Список удалён

# %% [markdown]
# #### Signatures

# %% [markdown]
# Получение всех классов сигнатур

# %%
from ptnad import PTNADClient
from ptnad.api.signatures import SignaturesAPI

client = PTNADClient("https://ptlab-nad.ptlab.ptsecurity.ru", verify_ssl=False)
client.set_auth(username="administrator", password="Administr@t0r")
client.login()

signatures = SignaturesAPI(client)

classes = signatures.get_classes()
for cls in classes:
    print(f"{cls['title']} (priority: {cls['priority']})")
# Out:
# Not suspicious traffic (priority: 3)
# Unknown traffic (priority: 3)
# Potentially bad traffic (priority: 2)
# Information leak attempt (priority: 2)
# DoS attack attempt (priority: 2)
# Attempt to gain user privileges (priority: 2)
# Attempt to gain administrator privileges (priority: 2)
# RPC query decoding (priority: 2)
# Executable code (priority: 1)
# Suspicious string (priority: 3)
# Unusual port used by a client (priority: 2)
# Network scan (priority: 3)
# DoS attack (priority: 2)
# Non-standard protocol or event (priority: 2)
# Generic protocol command decoding (priority: 3)
# Possible malware activity (priority: 2)
# Information leak (priority: 2)
# Large-scale information leak (priority: 2)
# Successful DoS attack (priority: 2)
# Unsuccessful user privilege gain (priority: 2)
# Successful user privilege gain (priority: 1)
# Successful administrator privilege gain (priority: 1)
# Access to a potentially vulnerable web application (priority: 2)
# Successful credential theft (priority: 1)
# Social engineering attempt (priority: 2)
# Crypto currency mining activity (priority: 2)
# Malware command and control activity (priority: 1)
# Tunneling traffic (priority: 1)
# Malicious redirect (priority: 2)
# Suspicious file name (priority: 2)
# Attempt to sign in with a suspicious account (priority: 2)
# System call (priority: 2)
# TCP connection (priority: 4)
# Network trojan (priority: 1)
# Web application attack (priority: 2)
# Misc. activity (priority: 3)
# Misc. attacks (priority: 2)
# Generic ICMP event (priority: 3)
# Inappropriate content (priority: 1)
# Potential corporate privacy violation (priority: 2)
# Attempt to sign in with default account (priority: 2)
# Exploitation attributes (priority: 1)
# Active Directory exploitation attributes (priority: 1)
# Suspicious Active Directory activity (priority: 2)
# Targeted malicious activity (priority: 1)
# Exploit kit activity (priority: 1)
# Device retrieval of external IP address (priority: 2)
# Domain used for command and control (priority: 1)
# Possibly unwanted program (priority: 2)

# %% [markdown]
# Получение полной информации по одной сигнатуре

# %%
rules = signatures.get_rules(search="ftp", cls="Network scan")

for r in rules:
    print(f"\nRule #{r['sid']} - {r['msg']}")
    print(f"Vendor: {r['vendor']}, Enabled: {r['enabled']}")
# Out:
# Rule #2007802 - ET SCAN Grim's Ping ftp scanning tool
# Vendor: ETOpen, Enabled: True
